# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define the action space
actions = ['charge', 'idle', 'discharge']

# Modify the get_state function to include the battery capacity
def get_state(price, demand, timestamp, battery_capacity):
    return (price, demand, timestamp, battery_capacity)

# %%
# Define battery parameters
battery_capacity = 500  # in watt hours
charge_discharge_rate = 20 # in watts per 15 minutes
initial_battery_state = battery_capacity / 2  # start with the battery half-charged

# Define the demand profile for a regular German private household within a workday

#demand_profile = [0.3, 0.2, 0.2, 0.2, 0.3, 0.4, 0.6, 0.8, 0.7, 0.6, 0.6, 0.6, 0.7, 0.7, 0.7, 0.8, 1.0, 1.2, 1.3, 1.2, 1.0, 0.8, 0.6, 0.4]
#demand_profile = [np.random.normal(item, 0.05, 4) for item in demand_profile]  # generate 4 random values around each item to get a value for every 15 minutes
#demand_profile = [item for sublist in demand_profile for item in sublist]  # flatten the list


# Define the average consumption for a 15-minute interval in Wh
avg_consumption_15min = (147 + 176) / 2
# Create a list to represent the electricity consumption over 24 hours
consumption_24h = [0]*20 + [avg_consumption_15min]*68 + [0]*8

#print legth of consumption_24h
print(len(consumption_24h))

# Modify the list to reflect that 90% of energy consumption happens between 5 am and 10 pm
consumption_24h_modified = [0.1 * avg_consumption_15min]*20 + [0.9 * avg_consumption_15min]*68 + [0.1 * avg_consumption_15min]*8
# Further modify the list to reflect that energy consumption varies over the day
# Assume that energy consumption is lower (70% of the average) from 9 am to 5 pm when household members are likely to be at school or work
for i in range(16, 64):  # indices corresponding to 9 am to 5 pm
    consumption_24h_modified[i] *= 0.7


# Define a function to add noise to the consumption values
def add_noise(consumption):
    noise = np.random.normal(0, 0.1 * consumption)
    return consumption + noise

# Apply the function to each element in the list
demand_profile = [add_noise(c) for c in consumption_24h_modified]

# print length of demand profile
print(len(demand_profile))

# Define the electricity cost for a german private household within a workday
#electricity_cost = [0.3, 0.2, 0.2, 0.2, 0.3, 0.4, 0.6, 0.8, 0.7, 0.6, 0.6, 0.6, 0.7, 0.7, 0.7, 0.8, 1.0, 1.2, 1.3, 1.2, 1.0, 0.8, 0.6, 0.4]
#electricity_cost = [np.random.normal(item, 0.05, 4) for item in electricity_cost]  # generate 4 random values around each item to get a value for every 15 minutes
#electricity_cost = [item for sublist in electricity_cost for item in sublist]  # flatten the list


# Define a function to calculate the electricity price based on consumption
def calculate_price(consumption):
    base_price = 0.3  # base price in euros per kWh
    price = base_price + 0.01 * consumption  # price increases with consumption
    return price

# Apply the function to each element in the list
prices_24h = [calculate_price(c) for c in demand_profile]

# Convert the prices from euros per kWh to euros per Wh
electricity_cost = [price / 1000 for price in prices_24h]



# Create a DataFrame with the demand profile and the electricity cost
df = pd.DataFrame({'demand': demand_profile, 'cost': electricity_cost})

# Attach datetime
df['datetime'] = pd.date_range(start='2023-07-05', periods=len(df), freq='15T')

# create new dataframe which is a copy of first 24 rows
df2 = df.iloc[0:24].copy()
# Out:
# 96
# 96

# %%
# Plot the demand profile and the electricity cost
plt.figure(figsize=(10, 5))

# Plot the demand profile
plt.subplot(1, 2, 1)
#plt.plot(df['datetime'], df['demand'])
plt.plot(df2['datetime'], df2['demand'])
plt.xlabel('Time')
plt.ylabel('Demand (W)')
plt.title('Demand Profile')

# Plot the electricity cost
plt.subplot(1, 2, 2)
plt.plot(df2['datetime'], df2['cost'])
#plt.plot(df['datetime'], df['cost'])
plt.xlabel('Time')
plt.ylabel('Cost (€/W)')
plt.title('Electricity Cost')

plt.tight_layout()
plt.show()

# %%
# Define the new reward function
def get_reward(state, action):
    current_price, current_demand, timestamp, battery_capacity = state

    print('#####')
    print('timestamp: ', timestamp)
    print('battery_capacity: ', battery_capacity)
    print('current_demand: ', current_demand)
    print('current_price: ', current_price)
    print('action: ', action)


    # Calculate the cost with the battery
    if action == 'discharge':
        battery_discharge = min(battery_capacity, current_demand)
        grid_demand = current_demand - battery_discharge

        print('action is battery_discharge: ', battery_discharge)
    elif action == 'charge':
        battery_charge = min(100 - battery_capacity, charge_discharge_rate)
        grid_demand = current_demand + battery_charge
    else:  # action == 'idle'
        grid_demand = current_demand

    cost_with_battery = grid_demand * current_price
    print('cost_with_battery: ', cost_with_battery)
    
    # Calculate the cost without the battery
    cost_without_battery = current_demand * current_price
    print('cost_without_battery: ', cost_without_battery)

    # The reward is the difference in costs
    reward = cost_without_battery - cost_with_battery
    print('reward: ', reward)
    print('#####')
    print("")

    return reward

# %%
# Initialize the Q-table to include the battery capacity in terms of watt hours
Q_table = {get_state(price, demand, timestamp, cap): {action: 0 for action in actions} for price in df['cost'] for demand in df['demand'] for timestamp in range(24) for cap in range(0, battery_capacity + 1)}

# %%
import random

# Parameters for Q-learning
alpha = 0.5  # learning rate
gamma = 0.9  # discount factor
num_iterations = 100  # number of iterations for exploration

# %%
# Define a function for the agent to select the best action in a state
def get_best_action(state):
    return max(Q_table[state], key=Q_table[state].get)

# %%
# Define the exploration rate
epsilon = 0.1

# Modify the exploration phase of Q-learning to include the battery capacity in terms of watt hours
total_rewards = []  # list to store the total reward in each episode

for _ in range(num_iterations):

    # Select a random state
    state = random.choice(list(Q_table.keys()))
    
    # Initialize total reward for this episode
    total_reward = 0
    battery_state = initial_battery_state  # reset the battery state at the start of each 
    
    for timestamp in range(24):  # 96 time steps (15 minutes each) in a 24-hour period
        
        # Update the state based on the current timestamp
        state = get_state(df2['cost'][timestamp], df2['demand'][timestamp], timestamp, battery_state)
   
        # Select an action
        if random.uniform(0, 1) < epsilon:
            # Exploration: select a random action
            action = random.choice(actions)
        else:
            # Exploitation: select the best action
            action = get_best_action(state)
        # Calculate the reward for the action
        reward = get_reward(state, action)
        total_reward += reward  # add the reward to the total reward for this episode
        # Update the battery capacity based on the action
        if action == 'charge':
            battery_state = min(battery_state + charge_discharge_rate, battery_capacity)
        elif action == 'discharge':
            battery_state = max(battery_state - charge_discharge_rate, 0)
        # Update the Q-value for the state-action pair
        Q_table[state][action] = (1 - alpha) * Q_table[state][action] + alpha * (reward + gamma * max(Q_table[state].values()))
    total_rewards.append(total_reward)  # store the total reward for this episode

# Plot the total reward in each episode
plt.plot(total_rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.show()
# Out:
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  charge
# cost_with_battery:  -0.0731793093346947
# cost_without_battery:  0.008779906921217518
# reward:  0.08195921625591222
# #####
#
# #####
# timestamp:  2
# battery_capacity:  290.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.08290360751118933
# cost_without_battery:  0.008824069716296899
# reward:  0.09172767722748623
# #####
#
# #####
# timestamp:  3
# battery_capacity:  310.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.08835163641638656
# cost_without_battery:  0.00699291892759924
# reward:  0.0953445553439858
# #####
#
# #####
# timestamp:  4
# battery_capacity:  330.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09931281246614519
# cost_without_battery:  0.007685827628751026
# reward:  0.10699864009489622
# #####
#
# #####
# timestamp:  5
# battery_capacity:  350.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.1043746172932456
# cost_without_battery:  0.006322511450011013
# reward:  0.11069712874325661
# #####
#
# #####
# timestamp:  6
# battery_capacity:  370.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  idle
# cost_with_battery:  0.006843968315336539
# cost_without_battery:  0.006843968315336539
# reward:  0.0
# #####
#
# #####
# timestamp:  7
# battery_capacity:  370.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.1171559423038573
# cost_without_battery:  0.007454475042849338
# reward:  0.12461041734670664
# #####
#
# #####
# timestamp:  8
# battery_capacity:  390.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.12509376509201398
# cost_without_battery:  0.0071048733109964225
# reward:  0.1321986384030104
# #####
#
# #####
# timestamp:  9
# battery_capacity:  410.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.13475320043828487
# cost_without_battery:  0.007238780971441822
# reward:  0.1419919814097267
# #####
#
# #####
# timestamp:  10
# battery_capacity:  430.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  charge
# cost_with_battery:  -0.13852844158305366
# cost_without_battery:  0.006051346236792425
# reward:  0.1445797878198461
# #####
#
# #####
# timestamp:  11
# battery_capacity:  450.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.1552376561207627
# cost_without_battery:  0.007707694212424944
# reward:  0.16294535033318766
# #####
#
# #####
# timestamp:  12
# battery_capacity:  470.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.1677772458014576
# cost_without_battery:  0.008385055478596446
# reward:  0.17616230128005403
# #####
#
# #####
# timestamp:  13
# battery_capacity:  490.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.17784230485746597
# cost_without_battery:  0.008494392657085409
# reward:  0.18633669751455137
# #####
#
# #####
# timestamp:  14
# battery_capacity:  500
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.17394717673323712
# cost_without_battery:  0.006873526448300802
# reward:  0.18082070318153792
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  discharge
# action is battery_discharge:  14.982069670958069
# cost_with_battery:  0.0
# cost_without_battery:  0.0067392450175418365
# reward:  0.0067392450175418365
# #####
#
# #####
# timestamp:  16
# battery_capacity:  480
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.1531451285105056
# cost_without_battery:  0.0048078246155639935
# reward:  0.1579529531260696
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  discharge
# action is battery_discharge:  11.236330903787973
# cost_with_battery:  0.0
# cost_without_battery:  0.004633450592930599
# reward:  0.004633450592930599
# #####
#
# #####
# timestamp:  19
# battery_capacity:  480
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.15359173343509222
# cost_without_battery:  0.004880638719276049
# reward:  0.15847237215436827
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  charge
# cost_with_battery:  -0.0731793093346947
# cost_without_battery:  0.008779906921217518
# reward:  0.08195921625591222
# #####
#
# #####
# timestamp:  2
# battery_capacity:  290.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.08290360751118933
# cost_without_battery:  0.008824069716296899
# reward:  0.09172767722748623
# #####
#
# #####
# timestamp:  3
# battery_capacity:  310.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.08835163641638656
# cost_without_battery:  0.00699291892759924
# reward:  0.0953445553439858
# #####
#
# #####
# timestamp:  4
# battery_capacity:  330.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09931281246614519
# cost_without_battery:  0.007685827628751026
# reward:  0.10699864009489622
# #####
#
# #####
# timestamp:  5
# battery_capacity:  350.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.1043746172932456
# cost_without_battery:  0.006322511450011013
# reward:  0.11069712874325661
# #####
#
# #####
# timestamp:  6
# battery_capacity:  370.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  charge
# cost_with_battery:  -0.11507779107292733
# cost_without_battery:  0.006843968315336539
# reward:  0.12192175938826387
# #####
#
# #####
# timestamp:  7
# battery_capacity:  390.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.12638634358879852
# cost_without_battery:  0.007454475042849338
# reward:  0.13384081863164787
# #####
#
# #####
# timestamp:  8
# battery_capacity:  410.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.13421091256808368
# cost_without_battery:  0.0071048733109964225
# reward:  0.1413157858790801
# #####
#
# #####
# timestamp:  9
# battery_capacity:  430.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.1439139734324608
# cost_without_battery:  0.007238780971441822
# reward:  0.1511527544039026
# #####
#
# #####
# timestamp:  10
# battery_capacity:  450.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  discharge
# action is battery_discharge:  13.812056915104874
# cost_with_battery:  0.0
# cost_without_battery:  0.006051346236792425
# reward:  0.006051346236792425
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  idle
# cost_with_battery:  0.006873526448300802
# cost_without_battery:  0.006873526448300802
# reward:  0.0
# #####
#
# #####
# timestamp:  15
# battery_capacity:  490.0
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  charge
# cost_with_battery:  -0.16869082669919463
# cost_without_battery:  0.0067392450175418365
# reward:  0.17543007171673647
# #####
#
# #####
# timestamp:  16
# battery_capacity:  500
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.16145844183293032
# cost_without_battery:  0.0048078246155639935
# reward:  0.16626626644849432
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  discharge
# action is battery_discharge:  11.236330903787973
# cost_with_battery:  0.0
# cost_without_battery:  0.004633450592930599
# reward:  0.004633450592930599
# #####
#
# #####
# timestamp:  19
# battery_capacity:  480
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.15359173343509222
# cost_without_battery:  0.004880638719276049
# reward:  0.15847237215436827
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  discharge
# action is battery_discharge:  100.28773080593817
# cost_with_battery:  0.0
# cost_without_battery:  0.13066260874382465
# reward:  0.13066260874382465
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  charge
# cost_with_battery:  -0.0731793093346947
# cost_without_battery:  0.008779906921217518
# reward:  0.08195921625591222
# #####
#
# #####
# timestamp:  2
# battery_capacity:  290.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.08290360751118933
# cost_without_battery:  0.008824069716296899
# reward:  0.09172767722748623
# #####
#
# #####
# timestamp:  3
# battery_capacity:  310.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.08835163641638656
# cost_without_battery:  0.00699291892759924
# reward:  0.0953445553439858
# #####
#
# #####
# timestamp:  4
# battery_capacity:  330.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09931281246614519
# cost_without_battery:  0.007685827628751026
# reward:  0.10699864009489622
# #####
#
# #####
# timestamp:  5
# battery_capacity:  350.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.1043746172932456
# cost_without_battery:  0.006322511450011013
# reward:  0.11069712874325661
# #####
#
# #####
# timestamp:  6
# battery_capacity:  370.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  charge
# cost_with_battery:  -0.11507779107292733
# cost_without_battery:  0.006843968315336539
# reward:  0.12192175938826387
# #####
#
# #####
# timestamp:  7
# battery_capacity:  390.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.12638634358879852
# cost_without_battery:  0.007454475042849338
# reward:  0.13384081863164787
# #####
#
# #####
# timestamp:  8
# battery_capacity:  410.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.13421091256808368
# cost_without_battery:  0.0071048733109964225
# reward:  0.1413157858790801
# #####
#
# #####
# timestamp:  9
# battery_capacity:  430.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.1439139734324608
# cost_without_battery:  0.007238780971441822
# reward:  0.1511527544039026
# #####
#
# #####
# timestamp:  10
# battery_capacity:  450.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  discharge
# action is battery_discharge:  13.812056915104874
# cost_with_battery:  0.0
# cost_without_battery:  0.006051346236792425
# reward:  0.006051346236792425
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16942665915369864
# cost_without_battery:  0.006873526448300802
# reward:  0.17630018560199945
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  discharge
# action is battery_discharge:  14.982069670958069
# cost_with_battery:  0.0
# cost_without_battery:  0.0067392450175418365
# reward:  0.0067392450175418365
# #####
#
# #####
# timestamp:  16
# battery_capacity:  480
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.1531451285105056
# cost_without_battery:  0.0048078246155639935
# reward:  0.1579529531260696
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  discharge
# action is battery_discharge:  11.236330903787973
# cost_with_battery:  0.0
# cost_without_battery:  0.004633450592930599
# reward:  0.004633450592930599
# #####
#
# #####
# timestamp:  19
# battery_capacity:  480
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.15359173343509222
# cost_without_battery:  0.004880638719276049
# reward:  0.15847237215436827
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  charge
# cost_with_battery:  -0.0731793093346947
# cost_without_battery:  0.008779906921217518
# reward:  0.08195921625591222
# #####
#
# #####
# timestamp:  2
# battery_capacity:  290.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.08290360751118933
# cost_without_battery:  0.008824069716296899
# reward:  0.09172767722748623
# #####
#
# #####
# timestamp:  3
# battery_capacity:  310.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.08835163641638656
# cost_without_battery:  0.00699291892759924
# reward:  0.0953445553439858
# #####
#
# #####
# timestamp:  4
# battery_capacity:  330.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09931281246614519
# cost_without_battery:  0.007685827628751026
# reward:  0.10699864009489622
# #####
#
# #####
# timestamp:  5
# battery_capacity:  350.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.1043746172932456
# cost_without_battery:  0.006322511450011013
# reward:  0.11069712874325661
# #####
#
# #####
# timestamp:  6
# battery_capacity:  370.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  charge
# cost_with_battery:  -0.11507779107292733
# cost_without_battery:  0.006843968315336539
# reward:  0.12192175938826387
# #####
#
# #####
# timestamp:  7
# battery_capacity:  390.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.12638634358879852
# cost_without_battery:  0.007454475042849338
# reward:  0.13384081863164787
# #####
#
# #####
# timestamp:  8
# battery_capacity:  410.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.13421091256808368
# cost_without_battery:  0.0071048733109964225
# reward:  0.1413157858790801
# #####
#
# #####
# timestamp:  9
# battery_capacity:  430.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.1439139734324608
# cost_without_battery:  0.007238780971441822
# reward:  0.1511527544039026
# #####
#
# #####
# timestamp:  10
# battery_capacity:  450.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  discharge
# action is battery_discharge:  13.812056915104874
# cost_with_battery:  0.0
# cost_without_battery:  0.006051346236792425
# reward:  0.006051346236792425
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16942665915369864
# cost_without_battery:  0.006873526448300802
# reward:  0.17630018560199945
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  discharge
# action is battery_discharge:  14.982069670958069
# cost_with_battery:  0.0
# cost_without_battery:  0.0067392450175418365
# reward:  0.0067392450175418365
# #####
#
# #####
# timestamp:  16
# battery_capacity:  480
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.1531451285105056
# cost_without_battery:  0.0048078246155639935
# reward:  0.1579529531260696
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  discharge
# action is battery_discharge:  11.236330903787973
# cost_with_battery:  0.0
# cost_without_battery:  0.004633450592930599
# reward:  0.004633450592930599
# #####
#
# #####
# timestamp:  19
# battery_capacity:  480
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.15359173343509222
# cost_without_battery:  0.004880638719276049
# reward:  0.15847237215436827
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  idle
# cost_with_battery:  0.008779906921217518
# cost_without_battery:  0.008779906921217518
# reward:  0.0
# #####
#
# #####
# timestamp:  2
# battery_capacity:  270.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.073248062539875
# cost_without_battery:  0.008824069716296899
# reward:  0.0820721322561719
# #####
#
# #####
# timestamp:  3
# battery_capacity:  290.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.0792712025741022
# cost_without_battery:  0.00699291892759924
# reward:  0.08626412150170143
# #####
#
# #####
# timestamp:  4
# battery_capacity:  310.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09000858289267595
# cost_without_battery:  0.007685827628751026
# reward:  0.09769441052142698
# #####
#
# #####
# timestamp:  5
# battery_capacity:  330.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.09551884699378506
# cost_without_battery:  0.006322511450011013
# reward:  0.10184135844379608
# #####
#
# #####
# timestamp:  6
# battery_capacity:  350.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  idle
# cost_with_battery:  0.006843968315336539
# cost_without_battery:  0.006843968315336539
# reward:  0.0
# #####
#
# #####
# timestamp:  7
# battery_capacity:  350.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.10792554101891606
# cost_without_battery:  0.007454475042849338
# reward:  0.1153800160617654
# #####
#
# #####
# timestamp:  8
# battery_capacity:  370.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.1159766176159443
# cost_without_battery:  0.0071048733109964225
# reward:  0.12308149092694072
# #####
#
# #####
# timestamp:  9
# battery_capacity:  390.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  idle
# cost_with_battery:  0.007238780971441822
# cost_without_battery:  0.007238780971441822
# reward:  0.0
# #####
#
# #####
# timestamp:  10
# battery_capacity:  390.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  charge
# cost_with_battery:  -0.1210036188170117
# cost_without_battery:  0.006051346236792425
# reward:  0.12705496505380412
# #####
#
# #####
# timestamp:  11
# battery_capacity:  410.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.1366153303683984
# cost_without_battery:  0.007707694212424944
# reward:  0.14432302458082336
# #####
#
# #####
# timestamp:  12
# battery_capacity:  430.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.1487326726901004
# cost_without_battery:  0.008385055478596446
# reward:  0.15711772816869685
# #####
#
# #####
# timestamp:  13
# battery_capacity:  450.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.15873084870212736
# cost_without_battery:  0.008494392657085409
# reward:  0.16722524135921277
# #####
#
# #####
# timestamp:  14
# battery_capacity:  470.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16038562399462175
# cost_without_battery:  0.006873526448300802
# reward:  0.16725915044292256
# #####
#
# #####
# timestamp:  15
# battery_capacity:  490.0
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  charge
# cost_with_battery:  -0.16869082669919463
# cost_without_battery:  0.0067392450175418365
# reward:  0.17543007171673647
# #####
#
# #####
# timestamp:  16
# battery_capacity:  500
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.16145844183293032
# cost_without_battery:  0.0048078246155639935
# reward:  0.16626626644849432
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  discharge
# action is battery_discharge:  11.236330903787973
# cost_with_battery:  0.0
# cost_without_battery:  0.004633450592930599
# reward:  0.004633450592930599
# #####
#
# #####
# timestamp:  19
# battery_capacity:  480
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.15359173343509222
# cost_without_battery:  0.004880638719276049
# reward:  0.15847237215436827
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  discharge
# action is battery_discharge:  18.211303679948365
# cost_with_battery:  0.0
# cost_without_battery:  0.008779906921217518
# reward:  0.008779906921217518
# #####
#
# #####
# timestamp:  2
# battery_capacity:  250.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.06359251756856066
# cost_without_battery:  0.008824069716296899
# reward:  0.07241658728485756
# #####
#
# #####
# timestamp:  3
# battery_capacity:  270.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.07019076873181783
# cost_without_battery:  0.00699291892759924
# reward:  0.07718368765941706
# #####
#
# #####
# timestamp:  4
# battery_capacity:  290.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.08070435331920672
# cost_without_battery:  0.007685827628751026
# reward:  0.08839018094795775
# #####
#
# #####
# timestamp:  5
# battery_capacity:  310.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.08666307669432453
# cost_without_battery:  0.006322511450011013
# reward:  0.09298558814433555
# #####
#
# #####
# timestamp:  6
# battery_capacity:  330.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  charge
# cost_with_battery:  -0.09701530820059194
# cost_without_battery:  0.006843968315336539
# reward:  0.10385927651592848
# #####
#
# #####
# timestamp:  7
# battery_capacity:  350.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.10792554101891606
# cost_without_battery:  0.007454475042849338
# reward:  0.1153800160617654
# #####
#
# #####
# timestamp:  8
# battery_capacity:  370.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.1159766176159443
# cost_without_battery:  0.0071048733109964225
# reward:  0.12308149092694072
# #####
#
# #####
# timestamp:  9
# battery_capacity:  390.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.12559242744410895
# cost_without_battery:  0.007238780971441822
# reward:  0.13283120841555077
# #####
#
# #####
# timestamp:  10
# battery_capacity:  410.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  charge
# cost_with_battery:  -0.1297660302000327
# cost_without_battery:  0.006051346236792425
# reward:  0.13581737643682512
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16942665915369864
# cost_without_battery:  0.006873526448300802
# reward:  0.17630018560199945
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  discharge
# action is battery_discharge:  14.982069670958069
# cost_with_battery:  0.0
# cost_without_battery:  0.0067392450175418365
# reward:  0.0067392450175418365
# #####
#
# #####
# timestamp:  16
# battery_capacity:  480
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.1531451285105056
# cost_without_battery:  0.0048078246155639935
# reward:  0.1579529531260696
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  discharge
# action is battery_discharge:  11.236330903787973
# cost_with_battery:  0.0
# cost_without_battery:  0.004633450592930599
# reward:  0.004633450592930599
# #####
#
# #####
# timestamp:  19
# battery_capacity:  480
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.15359173343509222
# cost_without_battery:  0.004880638719276049
# reward:  0.15847237215436827
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  charge
# cost_with_battery:  -0.0731793093346947
# cost_without_battery:  0.008779906921217518
# reward:  0.08195921625591222
# #####
#
# #####
# timestamp:  2
# battery_capacity:  290.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.08290360751118933
# cost_without_battery:  0.008824069716296899
# reward:  0.09172767722748623
# #####
#
# #####
# timestamp:  3
# battery_capacity:  310.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.08835163641638656
# cost_without_battery:  0.00699291892759924
# reward:  0.0953445553439858
# #####
#
# #####
# timestamp:  4
# battery_capacity:  330.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09931281246614519
# cost_without_battery:  0.007685827628751026
# reward:  0.10699864009489622
# #####
#
# #####
# timestamp:  5
# battery_capacity:  350.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.1043746172932456
# cost_without_battery:  0.006322511450011013
# reward:  0.11069712874325661
# #####
#
# #####
# timestamp:  6
# battery_capacity:  370.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  charge
# cost_with_battery:  -0.11507779107292733
# cost_without_battery:  0.006843968315336539
# reward:  0.12192175938826387
# #####
#
# #####
# timestamp:  7
# battery_capacity:  390.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.12638634358879852
# cost_without_battery:  0.007454475042849338
# reward:  0.13384081863164787
# #####
#
# #####
# timestamp:  8
# battery_capacity:  410.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  discharge
# action is battery_discharge:  15.585737380348414
# cost_with_battery:  0.0
# cost_without_battery:  0.0071048733109964225
# reward:  0.0071048733109964225
# #####
#
# #####
# timestamp:  9
# battery_capacity:  390.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.12559242744410895
# cost_without_battery:  0.007238780971441822
# reward:  0.13283120841555077
# #####
#
# #####
# timestamp:  10
# battery_capacity:  410.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  charge
# cost_with_battery:  -0.1297660302000327
# cost_without_battery:  0.006051346236792425
# reward:  0.13581737643682512
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16942665915369864
# cost_without_battery:  0.006873526448300802
# reward:  0.17630018560199945
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  discharge
# action is battery_discharge:  14.982069670958069
# cost_with_battery:  0.0
# cost_without_battery:  0.0067392450175418365
# reward:  0.0067392450175418365
# #####
#
# #####
# timestamp:  16
# battery_capacity:  480
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.1531451285105056
# cost_without_battery:  0.0048078246155639935
# reward:  0.1579529531260696
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  discharge
# action is battery_discharge:  10.349001189709565
# cost_with_battery:  0.0
# cost_without_battery:  0.00417571861315897
# reward:  0.00417571861315897
# #####
#
# #####
# timestamp:  18
# battery_capacity:  480
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  charge
# cost_with_battery:  -0.1520646068414637
# cost_without_battery:  0.004633450592930599
# reward:  0.1566980574343943
# #####
#
# #####
# timestamp:  19
# battery_capacity:  500
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.1619323846011116
# cost_without_battery:  0.004880638719276049
# reward:  0.16681302332038764
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  charge
# cost_with_battery:  -0.0731793093346947
# cost_without_battery:  0.008779906921217518
# reward:  0.08195921625591222
# #####
#
# #####
# timestamp:  2
# battery_capacity:  290.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.08290360751118933
# cost_without_battery:  0.008824069716296899
# reward:  0.09172767722748623
# #####
#
# #####
# timestamp:  3
# battery_capacity:  310.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.08835163641638656
# cost_without_battery:  0.00699291892759924
# reward:  0.0953445553439858
# #####
#
# #####
# timestamp:  4
# battery_capacity:  330.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09931281246614519
# cost_without_battery:  0.007685827628751026
# reward:  0.10699864009489622
# #####
#
# #####
# timestamp:  5
# battery_capacity:  350.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.1043746172932456
# cost_without_battery:  0.006322511450011013
# reward:  0.11069712874325661
# #####
#
# #####
# timestamp:  6
# battery_capacity:  370.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  charge
# cost_with_battery:  -0.11507779107292733
# cost_without_battery:  0.006843968315336539
# reward:  0.12192175938826387
# #####
#
# #####
# timestamp:  7
# battery_capacity:  390.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.12638634358879852
# cost_without_battery:  0.007454475042849338
# reward:  0.13384081863164787
# #####
#
# #####
# timestamp:  8
# battery_capacity:  410.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.13421091256808368
# cost_without_battery:  0.0071048733109964225
# reward:  0.1413157858790801
# #####
#
# #####
# timestamp:  9
# battery_capacity:  430.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.1439139734324608
# cost_without_battery:  0.007238780971441822
# reward:  0.1511527544039026
# #####
#
# #####
# timestamp:  10
# battery_capacity:  450.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  discharge
# action is battery_discharge:  13.812056915104874
# cost_with_battery:  0.0
# cost_without_battery:  0.006051346236792425
# reward:  0.006051346236792425
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16942665915369864
# cost_without_battery:  0.006873526448300802
# reward:  0.17630018560199945
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  discharge
# action is battery_discharge:  14.982069670958069
# cost_with_battery:  0.0
# cost_without_battery:  0.0067392450175418365
# reward:  0.0067392450175418365
# #####
#
# #####
# timestamp:  16
# battery_capacity:  480
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.1531451285105056
# cost_without_battery:  0.0048078246155639935
# reward:  0.1579529531260696
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# ...
# cost_without_battery:  0.007238780971441822
# reward:  0.1511527544039026
# #####
#
# #####
# timestamp:  10
# battery_capacity:  450.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  discharge
# action is battery_discharge:  13.812056915104874
# cost_with_battery:  0.0
# cost_without_battery:  0.006051346236792425
# reward:  0.006051346236792425
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16942665915369864
# cost_without_battery:  0.006873526448300802
# reward:  0.17630018560199945
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  charge
# cost_with_battery:  -0.17318903366629043
# cost_without_battery:  0.0067392450175418365
# reward:  0.17992827868383227
# #####
#
# #####
# timestamp:  16
# battery_capacity:  500
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.16145844183293032
# cost_without_battery:  0.0048078246155639935
# reward:  0.16626626644849432
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  charge
# cost_with_battery:  -0.16031187302222127
# cost_without_battery:  0.004633450592930599
# reward:  0.16494532361515188
# #####
#
# #####
# timestamp:  19
# battery_capacity:  500
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.1619323846011116
# cost_without_battery:  0.004880638719276049
# reward:  0.16681302332038764
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  charge
# cost_with_battery:  -0.0731793093346947
# cost_without_battery:  0.008779906921217518
# reward:  0.08195921625591222
# #####
#
# #####
# timestamp:  2
# battery_capacity:  290.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.08290360751118933
# cost_without_battery:  0.008824069716296899
# reward:  0.09172767722748623
# #####
#
# #####
# timestamp:  3
# battery_capacity:  310.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.08835163641638656
# cost_without_battery:  0.00699291892759924
# reward:  0.0953445553439858
# #####
#
# #####
# timestamp:  4
# battery_capacity:  330.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09931281246614519
# cost_without_battery:  0.007685827628751026
# reward:  0.10699864009489622
# #####
#
# #####
# timestamp:  5
# battery_capacity:  350.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.1043746172932456
# cost_without_battery:  0.006322511450011013
# reward:  0.11069712874325661
# #####
#
# #####
# timestamp:  6
# battery_capacity:  370.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  charge
# cost_with_battery:  -0.11507779107292733
# cost_without_battery:  0.006843968315336539
# reward:  0.12192175938826387
# #####
#
# #####
# timestamp:  7
# battery_capacity:  390.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.12638634358879852
# cost_without_battery:  0.007454475042849338
# reward:  0.13384081863164787
# #####
#
# #####
# timestamp:  8
# battery_capacity:  410.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.13421091256808368
# cost_without_battery:  0.0071048733109964225
# reward:  0.1413157858790801
# #####
#
# #####
# timestamp:  9
# battery_capacity:  430.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.1439139734324608
# cost_without_battery:  0.007238780971441822
# reward:  0.1511527544039026
# #####
#
# #####
# timestamp:  10
# battery_capacity:  450.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  discharge
# action is battery_discharge:  13.812056915104874
# cost_with_battery:  0.0
# cost_without_battery:  0.006051346236792425
# reward:  0.006051346236792425
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16942665915369864
# cost_without_battery:  0.006873526448300802
# reward:  0.17630018560199945
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  charge
# cost_with_battery:  -0.17318903366629043
# cost_without_battery:  0.0067392450175418365
# reward:  0.17992827868383227
# #####
#
# #####
# timestamp:  16
# battery_capacity:  500
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.16145844183293032
# cost_without_battery:  0.0048078246155639935
# reward:  0.16626626644849432
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  charge
# cost_with_battery:  -0.16031187302222127
# cost_without_battery:  0.004633450592930599
# reward:  0.16494532361515188
# #####
#
# #####
# timestamp:  19
# battery_capacity:  500
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.1619323846011116
# cost_without_battery:  0.004880638719276049
# reward:  0.16681302332038764
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####
#
# #####
# timestamp:  0
# battery_capacity:  250.0
# current_demand:  16.419120738115513
# current_price:  0.00046419120738115514
# action:  charge
# cost_with_battery:  -0.06200706962761047
# cost_without_battery:  0.007621611479562803
# reward:  0.06962868110717327
# #####
#
# #####
# timestamp:  1
# battery_capacity:  270.0
# current_demand:  18.211303679948365
# current_price:  0.00048211303679948365
# action:  charge
# cost_with_battery:  -0.0731793093346947
# cost_without_battery:  0.008779906921217518
# reward:  0.08195921625591222
# #####
#
# #####
# timestamp:  2
# battery_capacity:  290.0
# current_demand:  18.277724856571698
# current_price:  0.000482777248565717
# action:  charge
# cost_with_battery:  -0.08290360751118933
# cost_without_battery:  0.008824069716296899
# reward:  0.09172767722748623
# #####
#
# #####
# timestamp:  3
# battery_capacity:  310.0
# current_demand:  15.402169211421807
# current_price:  0.0004540216921142181
# action:  charge
# cost_with_battery:  -0.08835163641638656
# cost_without_battery:  0.00699291892759924
# reward:  0.0953445553439858
# #####
#
# #####
# timestamp:  4
# battery_capacity:  330.0
# current_demand:  16.52114786734618
# current_price:  0.0004652114786734618
# action:  charge
# cost_with_battery:  -0.09931281246614519
# cost_without_battery:  0.007685827628751026
# reward:  0.10699864009489622
# #####
#
# #####
# timestamp:  5
# battery_capacity:  350.0
# current_demand:  14.278851497302645
# current_price:  0.0004427885149730264
# action:  charge
# cost_with_battery:  -0.1043746172932456
# cost_without_battery:  0.006322511450011013
# reward:  0.11069712874325661
# #####
#
# #####
# timestamp:  6
# battery_capacity:  370.0
# current_demand:  15.156207180838475
# current_price:  0.0004515620718083847
# action:  charge
# cost_with_battery:  -0.11507779107292733
# cost_without_battery:  0.006843968315336539
# reward:  0.12192175938826387
# #####
#
# #####
# timestamp:  7
# battery_capacity:  390.0
# current_demand:  16.15200642470616
# current_price:  0.0004615200642470616
# action:  charge
# cost_with_battery:  -0.12638634358879852
# cost_without_battery:  0.007454475042849338
# reward:  0.13384081863164787
# #####
#
# #####
# timestamp:  8
# battery_capacity:  410.0
# current_demand:  15.585737380348414
# current_price:  0.00045585737380348415
# action:  charge
# cost_with_battery:  -0.13421091256808368
# cost_without_battery:  0.0071048733109964225
# reward:  0.1413157858790801
# #####
#
# #####
# timestamp:  9
# battery_capacity:  430.0
# current_demand:  15.803864970879582
# current_price:  0.00045803864970879585
# action:  charge
# cost_with_battery:  -0.1439139734324608
# cost_without_battery:  0.007238780971441822
# reward:  0.1511527544039026
# #####
#
# #####
# timestamp:  10
# battery_capacity:  450.0
# current_demand:  13.812056915104874
# current_price:  0.0004381205691510487
# action:  discharge
# action is battery_discharge:  13.812056915104874
# cost_with_battery:  0.0
# cost_without_battery:  0.006051346236792425
# reward:  0.006051346236792425
# #####
#
# #####
# timestamp:  11
# battery_capacity:  430.0
# current_demand:  16.55581438091076
# current_price:  0.0004655581438091076
# action:  charge
# cost_with_battery:  -0.14592649324458057
# cost_without_battery:  0.007707694212424944
# reward:  0.15363418745700552
# #####
#
# #####
# timestamp:  12
# battery_capacity:  450.0
# current_demand:  17.611432778392988
# current_price:  0.00047611432778392986
# action:  charge
# cost_with_battery:  -0.15825495924577898
# cost_without_battery:  0.008385055478596446
# reward:  0.16664001472437542
# #####
#
# #####
# timestamp:  13
# battery_capacity:  470.0
# current_demand:  17.77864038834651
# current_price:  0.00047778640388346504
# action:  charge
# cost_with_battery:  -0.16828657677979666
# cost_without_battery:  0.008494392657085409
# reward:  0.17678096943688207
# #####
#
# #####
# timestamp:  14
# battery_capacity:  490.0
# current_demand:  15.205175795384475
# current_price:  0.0004520517579538448
# action:  charge
# cost_with_battery:  -0.16942665915369864
# cost_without_battery:  0.006873526448300802
# reward:  0.17630018560199945
# #####
#
# #####
# timestamp:  15
# battery_capacity:  500
# current_demand:  14.982069670958069
# current_price:  0.0004498206967095807
# action:  charge
# cost_with_battery:  -0.17318903366629043
# cost_without_battery:  0.0067392450175418365
# reward:  0.17992827868383227
# #####
#
# #####
# timestamp:  16
# battery_capacity:  500
# current_demand:  11.56656661212358
# current_price:  0.00041566566612123577
# action:  charge
# cost_with_battery:  -0.16145844183293032
# cost_without_battery:  0.0048078246155639935
# reward:  0.16626626644849432
# #####
#
# #####
# timestamp:  17
# battery_capacity:  500
# current_demand:  10.349001189709565
# current_price:  0.00040349001189709567
# action:  charge
# cost_with_battery:  -0.1572202861456793
# cost_without_battery:  0.00417571861315897
# reward:  0.16139600475883825
# #####
#
# #####
# timestamp:  18
# battery_capacity:  500
# current_demand:  11.236330903787973
# current_price:  0.0004123633090378797
# action:  charge
# cost_with_battery:  -0.16031187302222127
# cost_without_battery:  0.004633450592930599
# reward:  0.16494532361515188
# #####
#
# #####
# timestamp:  19
# battery_capacity:  500
# current_demand:  11.703255830096916
# current_price:  0.0004170325583009691
# action:  charge
# cost_with_battery:  -0.1619323846011116
# cost_without_battery:  0.004880638719276049
# reward:  0.16681302332038764
# #####
#
# #####
# timestamp:  20
# battery_capacity:  500
# current_demand:  115.9553585153509
# current_price:  0.0014595535851535091
# action:  charge
# cost_with_battery:  -0.41457837482256277
# cost_without_battery:  0.1692430592388409
# reward:  0.5838214340614036
# #####
#
# #####
# timestamp:  21
# battery_capacity:  500
# current_demand:  72.25005323701214
# current_price:  0.0010225005323701213
# action:  charge
# cost_with_battery:  -0.335124495049434
# cost_without_battery:  0.07387571789861451
# reward:  0.4090002129480485
# #####
#
# #####
# timestamp:  22
# battery_capacity:  500
# current_demand:  112.3305005487278
# current_price:  0.001423305005487278
# action:  charge
# cost_with_battery:  -0.4094414384950155
# cost_without_battery:  0.1598805636998957
# reward:  0.5693220021949112
# #####
#
# #####
# timestamp:  23
# battery_capacity:  500
# current_demand:  100.28773080593817
# current_price:  0.0013028773080593819
# action:  charge
# cost_with_battery:  -0.3904883144799281
# cost_without_battery:  0.13066260874382465
# reward:  0.5211509232237528
# #####

# %%
# Calculate the cumulative reward for each episode
cumulative_rewards = np.cumsum(total_rewards)
# Plot the cumulative reward of each episode
plt.plot(cumulative_rewards)
plt.xlabel('Episode')
plt.ylabel('Cumulative Reward')
plt.title('Cumulative Reward over Episodes')
plt.show()

# %%
# Print the final Q-table
#for state, actions in Q_table.items():
#    print(f'State: {state}')
#    for action, Q_value in actions.items():
#        print(f'    Action: {action}, Q-value: {Q_value}')

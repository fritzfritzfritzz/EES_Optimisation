# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define the action space
actions = ['charge', 'idle', 'discharge']

# Modify the get_state function to include the battery capacity
def get_state(price, demand, timestamp, battery_capacity):
    return (price, demand, timestamp, battery_capacity)

# %%
# Define battery parameters
max_battery_capacity = 400  # in watt hours
battery_capacity = 400  # in watt hours
charge_discharge_rate = 20 # in watts per 15 minutes
initial_battery_state = battery_capacity / 4  # start with the battery half-charged

timepoints = 24


# Define the demand profile for a regular German private household within a workday

# Define the average consumption for a 15-minute interval in Wh
avg_consumption_15min = (147 + 176) / 2

# Create a list to represent the electricity consumption over 24 hours
consumption_24h = [0]*20 + [avg_consumption_15min]*68 + [0]*8

#print legth of consumption_24h
print(len(consumption_24h))

# Modify the list to reflect that 90% of energy consumption happens between 5 am and 10 pm
consumption_24h_modified = [0.1 * avg_consumption_15min]*20 + [0.9 * avg_consumption_15min]*68 + [0.1 * avg_consumption_15min]*8
# Further modify the list to reflect that energy consumption varies over the day
# Assume that energy consumption is lower (70% of the average) from 9 am to 5 pm when household members are likely to be at school or work
for i in range(16, 64):  # indices corresponding to 9 am to 5 pm
    consumption_24h_modified[i] *= 0.7


# Define a function to add noise to the consumption values
def add_noise(consumption):
    noise = np.random.normal(0, 0.1 * consumption)
    return consumption + noise

# Apply the function to each element in the list
demand_profile = [add_noise(c) for c in consumption_24h_modified]

# print length of demand profile
print(len(demand_profile))



# Define a function to calculate the electricity price based on consumption
def calculate_price(consumption):
    base_price = 0.3  # base price in euros per kWh
    price = base_price + 0.01 * consumption  # price increases with consumption
    return price

# Apply the function to each element in the list
prices_24h = [calculate_price(c) for c in demand_profile]

# Convert the prices from euros per kWh to euros per Wh
electricity_cost = [price / 1000 for price in prices_24h]

# Create a DataFrame with the demand profile and the electricity cost
df = pd.DataFrame({'demand': demand_profile, 'cost': electricity_cost})

# Attach datetime
df['datetime'] = pd.date_range(start='2023-07-05', periods=len(df), freq='15T')

# create new dataframe which is a copy of first 8 rows
df2 = df.iloc[0:timepoints].copy()
# Out:
# 96
# 96

# %%
df2
# Out:
#         demand      cost            datetime
# 0    18.635510  0.000486 2023-07-05 00:00:00
# 1    15.585481  0.000456 2023-07-05 00:15:00
# 2    16.587941  0.000466 2023-07-05 00:30:00
# 3    16.379069  0.000464 2023-07-05 00:45:00
# 4    13.105302  0.000431 2023-07-05 01:00:00
# 5    15.482126  0.000455 2023-07-05 01:15:00
# 6    16.860855  0.000469 2023-07-05 01:30:00
# 7    15.365196  0.000454 2023-07-05 01:45:00
# 8    18.891816  0.000489 2023-07-05 02:00:00
# 9    15.255188  0.000453 2023-07-05 02:15:00
# 10   14.784539  0.000448 2023-07-05 02:30:00
# 11   14.092480  0.000441 2023-07-05 02:45:00
# 12   17.665836  0.000477 2023-07-05 03:00:00
# 13   17.922923  0.000479 2023-07-05 03:15:00
# 14   17.016445  0.000470 2023-07-05 03:30:00
# 15   16.455476  0.000465 2023-07-05 03:45:00
# 16   10.792369  0.000408 2023-07-05 04:00:00
# 17   12.189920  0.000422 2023-07-05 04:15:00
# 18   13.087601  0.000431 2023-07-05 04:30:00
# 19   11.983682  0.000420 2023-07-05 04:45:00
# 20  100.975965  0.001310 2023-07-05 05:00:00
# 21   86.642146  0.001166 2023-07-05 05:15:00
# 22  121.265306  0.001513 2023-07-05 05:30:00
# 23  114.177142  0.001442 2023-07-05 05:45:00

# %%
# Plot the demand profile and the electricity cost
plt.figure(figsize=(10, 5))

# Plot the demand profile
plt.subplot(1, 2, 1)
#plt.plot(df['datetime'], df['demand'])
plt.plot(df2['datetime'], df2['demand'])
plt.xlabel('Time')
plt.ylabel('Demand (W)')
plt.title('Demand Profile')

# Plot the electricity cost
plt.subplot(1, 2, 2)
plt.plot(df2['datetime'], df2['cost'])
#plt.plot(df['datetime'], df['cost'])
plt.xlabel('Time')
plt.ylabel('Cost (€/W)')
plt.title('Electricity Cost')

plt.tight_layout()
plt.show()

# %%
# Define the new reward function
def get_reward(state, action):
    current_price, current_demand, timestamp, battery_capacity = state

    print('#####')
    print('timestamp: ', timestamp)
    print('battery_capacity: ', battery_capacity)
    print('current_demand: ', current_demand)
    print('current_price: ', current_price)
    print('action: ', action)


    # Calculate the cost with the battery
    if action == 'discharge':
        battery_discharge = min(battery_capacity, current_demand)
        grid_demand = current_demand - battery_discharge

        print('action is battery_discharge: ', battery_discharge)
    elif action == 'charge':
        battery_charge = min(max_battery_capacity - battery_capacity, charge_discharge_rate)
        grid_demand = current_demand + battery_charge
    else:  # action == 'idle'
        grid_demand = current_demand

    cost_with_battery = grid_demand * current_price
    print('cost_with_battery: ', cost_with_battery)
    
    # Calculate the cost without the battery
    cost_without_battery = current_demand * current_price
    print('cost_without_battery: ', cost_without_battery)

    # The reward is the difference in costs
    reward = cost_without_battery - cost_with_battery
    print('reward: ', reward)
    print('#####')
    print("")

    return reward

# %%
# Initialize the Q-table to include the battery capacity in terms of watt hours
Q_table = {get_state(price, demand, timestamp, cap): {action: 0 for action in actions} for price in df['cost'] for demand in df['demand'] for timestamp in range(timepoints) for cap in range(0, battery_capacity + 1)}

# %%
import random

# Parameters for Q-learning
alpha = 0.5  # learning rate
gamma = 0.9  # discount factor
num_iterations = 100  # number of iterations for exploration

# %%
# Define a function for the agent to select the best action in a state
def get_best_action(state):
    return max(Q_table[state], key=Q_table[state].get)

# %%
# Define the exploration rate
epsilon = 0.1

# Modify the exploration phase of Q-learning to include the battery capacity in terms of watt hours
total_rewards = []  # list to store the total reward in each episode

for _ in range(num_iterations):

    # Select a random state
    state = random.choice(list(Q_table.keys()))
    
    # Initialize total reward for this episode
    total_reward = 0
    battery_state = initial_battery_state  # reset the battery state at the start of each 
    
    for timestamp in range(timepoints):  # 8 time steps (15 minutes each) in a 24-hour period
        
        # Update the state based on the current timestamp
        state = get_state(df2['cost'][timestamp], df2['demand'][timestamp], timestamp, battery_state)
   
        # Select an action
        if random.uniform(0, 1) < epsilon:
            # Exploration: select a random action
            action = random.choice(actions)
        else:
            # Exploitation: select the best action
            action = get_best_action(state)
        # Calculate the reward for the action
        reward = get_reward(state, action)
        total_reward += reward  # add the reward to the total reward for this episode
        # Update the battery capacity based on the action
        if action == 'charge':
            battery_state = min(battery_state + charge_discharge_rate, battery_capacity)
        elif action == 'discharge':
            battery_state = max(battery_state - charge_discharge_rate, 0)
        # Update the Q-value for the state-action pair
        Q_table[state][action] = (1 - alpha) * Q_table[state][action] + alpha * (reward + gamma * max(Q_table[state].values()))
    total_rewards.append(total_reward)  # store the total reward for this episode

# Plot the total reward in each episode
plt.plot(total_rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.show()
# Out:
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  charge
# cost_with_battery:  0.01879057764706799
# cost_without_battery:  0.009063475574313713
# reward:  -0.009727102072754276
# #####
#
# #####
# timestamp:  1
# battery_capacity:  120.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  charge
# cost_with_battery:  0.016221812670707436
# cost_without_battery:  0.007104716473000415
# reward:  -0.00911709619770702
# #####
#
# #####
# timestamp:  2
# battery_capacity:  140.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  charge
# cost_with_battery:  0.01704556869252556
# cost_without_battery:  0.007727980414057924
# reward:  -0.009317588278467638
# #####
#
# #####
# timestamp:  3
# battery_capacity:  160.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  charge
# cost_with_battery:  0.016872273728930284
# cost_without_battery:  0.007596459876763167
# reward:  -0.009275813852167117
# #####
#
# #####
# timestamp:  4
# battery_capacity:  180.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  charge
# cost_with_battery:  0.014270140718695234
# cost_without_battery:  0.005649080236401385
# reward:  -0.008621060482293849
# #####
#
# #####
# timestamp:  5
# battery_capacity:  200.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  charge
# cost_with_battery:  0.01613802528163363
# cost_without_battery:  0.007041600075004809
# reward:  -0.00909642520662882
# #####
#
# #####
# timestamp:  6
# battery_capacity:  220.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  charge
# cost_with_battery:  0.017273311877481375
# cost_without_battery:  0.007901140862151749
# reward:  -0.009372171015329627
# #####
#
# #####
# timestamp:  7
# battery_capacity:  240.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  idle
# cost_with_battery:  0.0069704510563527
# cost_without_battery:  0.0069704510563527
# reward:  0.0
# #####
#
# #####
# timestamp:  8
# battery_capacity:  240.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  charge
# cost_with_battery:  0.01901491471884383
# cost_without_battery:  0.00923655160973429
# reward:  -0.009778363109109539
# #####
#
# #####
# timestamp:  9
# battery_capacity:  260.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  discharge
# action is battery_discharge:  15.255188193282766
# cost_with_battery:  0.0
# cost_without_battery:  0.00690376412610957
# reward:  0.00690376412610957
# #####
#
# #####
# timestamp:  10
# battery_capacity:  240.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  charge
# cost_with_battery:  0.015578095721321376
# cost_without_battery:  0.006621187849208898
# reward:  -0.008956907872112478
# #####
#
# #####
# timestamp:  11
# battery_capacity:  260.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  charge
# cost_with_battery:  0.015032220278380234
# cost_without_battery:  0.006213724188113198
# reward:  -0.008818496090267035
# #####
#
# #####
# timestamp:  12
# battery_capacity:  280.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  charge
# cost_with_battery:  0.017953735578226833
# cost_without_battery:  0.00842056838703063
# reward:  -0.009533167191196203
# #####
#
# #####
# timestamp:  13
# battery_capacity:  300.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  idle
# cost_with_battery:  0.008589188816069742
# cost_without_battery:  0.008589188816069742
# reward:  0.0
# #####
#
# #####
# timestamp:  14
# battery_capacity:  300.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  charge
# cost_with_battery:  0.017403816315930073
# cost_without_battery:  0.008000527360781601
# reward:  -0.009403288955148472
# #####
#
# #####
# timestamp:  15
# battery_capacity:  320.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  charge
# cost_with_battery:  0.016935564701373064
# cost_without_battery:  0.00764446955021889
# reward:  -0.009291095151154175
# #####
#
# #####
# timestamp:  16
# battery_capacity:  340.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  charge
# cost_with_battery:  0.01256093661232964
# cost_without_battery:  0.004402462860941112
# reward:  -0.008158473751388527
# #####
#
# #####
# timestamp:  17
# battery_capacity:  360.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  charge
# cost_with_battery:  0.013580901622242828
# cost_without_battery:  0.005142917588314595
# reward:  -0.008437984033928233
# #####
#
# #####
# timestamp:  18
# battery_capacity:  380.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  charge
# cost_with_battery:  0.014256653308666267
# cost_without_battery:  0.005639133158731313
# reward:  -0.008617520149934953
# #####
#
# #####
# timestamp:  19
# battery_capacity:  400.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  charge
# cost_with_battery:  0.0050311910203113125
# cost_without_battery:  0.0050311910203113125
# reward:  0.0
# #####
#
# #####
# timestamp:  20
# battery_capacity:  400
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  charge
# cost_with_battery:  0.132254245209227
# cost_without_battery:  0.132254245209227
# reward:  0.0
# #####
#
# #####
# timestamp:  21
# battery_capacity:  400
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  charge
# cost_with_battery:  0.10106125774188911
# cost_without_battery:  0.10106125774188911
# reward:  0.0
# #####
#
# #####
# timestamp:  22
# battery_capacity:  400
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  charge
# cost_with_battery:  0.18343233490610006
# cost_without_battery:  0.18343233490610006
# reward:  0.0
# #####
#
# #####
# timestamp:  23
# battery_capacity:  400
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  charge
# cost_with_battery:  0.16461733895050235
# cost_without_battery:  0.16461733895050235
# reward:  0.0
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  idle
# cost_with_battery:  0.009063475574313713
# cost_without_battery:  0.009063475574313713
# reward:  0.0
# #####
#
# #####
# timestamp:  1
# battery_capacity:  100.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  charge
# cost_with_battery:  0.016221812670707436
# cost_without_battery:  0.007104716473000415
# reward:  -0.00911709619770702
# #####
#
# #####
# timestamp:  2
# battery_capacity:  120.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  charge
# cost_with_battery:  0.01704556869252556
# cost_without_battery:  0.007727980414057924
# reward:  -0.009317588278467638
# #####
#
# #####
# timestamp:  3
# battery_capacity:  140.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  discharge
# action is battery_discharge:  16.379069260835585
# cost_with_battery:  0.0
# cost_without_battery:  0.007596459876763167
# reward:  0.007596459876763167
# #####
#
# #####
# timestamp:  4
# battery_capacity:  120.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  charge
# cost_with_battery:  0.014270140718695234
# cost_without_battery:  0.005649080236401385
# reward:  -0.008621060482293849
# #####
#
# #####
# timestamp:  5
# battery_capacity:  140.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  charge
# cost_with_battery:  0.01613802528163363
# cost_without_battery:  0.007041600075004809
# reward:  -0.00909642520662882
# #####
#
# #####
# timestamp:  6
# battery_capacity:  160.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  charge
# cost_with_battery:  0.017273311877481375
# cost_without_battery:  0.007901140862151749
# reward:  -0.009372171015329627
# #####
#
# #####
# timestamp:  7
# battery_capacity:  180.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  charge
# cost_with_battery:  0.016043490182310213
# cost_without_battery:  0.0069704510563527
# reward:  -0.009073039125957513
# #####
#
# #####
# timestamp:  8
# battery_capacity:  200.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  charge
# cost_with_battery:  0.01901491471884383
# cost_without_battery:  0.00923655160973429
# reward:  -0.009778363109109539
# #####
#
# #####
# timestamp:  9
# battery_capacity:  220.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  charge
# cost_with_battery:  0.015954801764766123
# cost_without_battery:  0.00690376412610957
# reward:  -0.009051037638656553
# #####
#
# #####
# timestamp:  10
# battery_capacity:  240.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  discharge
# action is battery_discharge:  14.784539360562382
# cost_with_battery:  0.0
# cost_without_battery:  0.006621187849208898
# reward:  0.006621187849208898
# #####
#
# #####
# timestamp:  11
# battery_capacity:  220.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  charge
# cost_with_battery:  0.015032220278380234
# cost_without_battery:  0.006213724188113198
# reward:  -0.008818496090267035
# #####
#
# #####
# timestamp:  12
# battery_capacity:  240.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  idle
# cost_with_battery:  0.00842056838703063
# cost_without_battery:  0.00842056838703063
# reward:  0.0
# #####
#
# #####
# timestamp:  13
# battery_capacity:  240.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  charge
# cost_with_battery:  0.018173773485149407
# cost_without_battery:  0.008589188816069742
# reward:  -0.009584584669079665
# #####
#
# #####
# timestamp:  14
# battery_capacity:  260.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  charge
# cost_with_battery:  0.017403816315930073
# cost_without_battery:  0.008000527360781601
# reward:  -0.009403288955148472
# #####
#
# #####
# timestamp:  15
# battery_capacity:  280.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  charge
# cost_with_battery:  0.016935564701373064
# cost_without_battery:  0.00764446955021889
# reward:  -0.009291095151154175
# #####
#
# #####
# timestamp:  16
# battery_capacity:  300.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  charge
# cost_with_battery:  0.01256093661232964
# cost_without_battery:  0.004402462860941112
# reward:  -0.008158473751388527
# #####
#
# #####
# timestamp:  17
# battery_capacity:  320.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  discharge
# action is battery_discharge:  12.189920169641168
# cost_with_battery:  0.0
# cost_without_battery:  0.005142917588314595
# reward:  0.005142917588314595
# #####
#
# #####
# timestamp:  18
# battery_capacity:  300.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  charge
# cost_with_battery:  0.014256653308666267
# cost_without_battery:  0.005639133158731313
# reward:  -0.008617520149934953
# #####
#
# #####
# timestamp:  19
# battery_capacity:  320.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  charge
# cost_with_battery:  0.013427927449047226
# cost_without_battery:  0.0050311910203113125
# reward:  -0.008396736428735913
# #####
#
# #####
# timestamp:  20
# battery_capacity:  340.0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  charge
# cost_with_battery:  0.1584494382637568
# cost_without_battery:  0.132254245209227
# reward:  -0.026195193054529803
# #####
#
# #####
# timestamp:  21
# battery_capacity:  360.0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  charge
# cost_with_battery:  0.12438968687371227
# cost_without_battery:  0.10106125774188911
# reward:  -0.02332842913182316
# #####
#
# #####
# timestamp:  22
# battery_capacity:  380.0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  charge
# cost_with_battery:  0.21368539601167863
# cost_without_battery:  0.18343233490610006
# reward:  -0.03025306110557857
# #####
#
# #####
# timestamp:  23
# battery_capacity:  400.0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  charge
# cost_with_battery:  0.16461733895050235
# cost_without_battery:  0.16461733895050235
# reward:  0.0
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  idle
# cost_with_battery:  0.009063475574313713
# cost_without_battery:  0.009063475574313713
# reward:  0.0
# #####
#
# #####
# timestamp:  1
# battery_capacity:  100.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  idle
# cost_with_battery:  0.007104716473000415
# cost_without_battery:  0.007104716473000415
# reward:  0.0
# #####
#
# #####
# timestamp:  2
# battery_capacity:  100.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  charge
# cost_with_battery:  0.01704556869252556
# cost_without_battery:  0.007727980414057924
# reward:  -0.009317588278467638
# #####
#
# #####
# timestamp:  3
# battery_capacity:  120.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  charge
# cost_with_battery:  0.016872273728930284
# cost_without_battery:  0.007596459876763167
# reward:  -0.009275813852167117
# #####
#
# #####
# timestamp:  4
# battery_capacity:  140.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  charge
# cost_with_battery:  0.014270140718695234
# cost_without_battery:  0.005649080236401385
# reward:  -0.008621060482293849
# #####
#
# #####
# timestamp:  5
# battery_capacity:  160.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  charge
# cost_with_battery:  0.01613802528163363
# cost_without_battery:  0.007041600075004809
# reward:  -0.00909642520662882
# #####
#
# #####
# timestamp:  6
# battery_capacity:  180.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  charge
# cost_with_battery:  0.017273311877481375
# cost_without_battery:  0.007901140862151749
# reward:  -0.009372171015329627
# #####
#
# #####
# timestamp:  7
# battery_capacity:  200.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  charge
# cost_with_battery:  0.016043490182310213
# cost_without_battery:  0.0069704510563527
# reward:  -0.009073039125957513
# #####
#
# #####
# timestamp:  8
# battery_capacity:  220.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  charge
# cost_with_battery:  0.01901491471884383
# cost_without_battery:  0.00923655160973429
# reward:  -0.009778363109109539
# #####
#
# #####
# timestamp:  9
# battery_capacity:  240.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  idle
# cost_with_battery:  0.00690376412610957
# cost_without_battery:  0.00690376412610957
# reward:  0.0
# #####
#
# #####
# timestamp:  10
# battery_capacity:  240.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  discharge
# action is battery_discharge:  14.784539360562382
# cost_with_battery:  0.0
# cost_without_battery:  0.006621187849208898
# reward:  0.006621187849208898
# #####
#
# #####
# timestamp:  11
# battery_capacity:  220.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  idle
# cost_with_battery:  0.006213724188113198
# cost_without_battery:  0.006213724188113198
# reward:  0.0
# #####
#
# #####
# timestamp:  12
# battery_capacity:  220.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  charge
# cost_with_battery:  0.017953735578226833
# cost_without_battery:  0.00842056838703063
# reward:  -0.009533167191196203
# #####
#
# #####
# timestamp:  13
# battery_capacity:  240.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  idle
# cost_with_battery:  0.008589188816069742
# cost_without_battery:  0.008589188816069742
# reward:  0.0
# #####
#
# #####
# timestamp:  14
# battery_capacity:  240.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  charge
# cost_with_battery:  0.017403816315930073
# cost_without_battery:  0.008000527360781601
# reward:  -0.009403288955148472
# #####
#
# #####
# timestamp:  15
# battery_capacity:  260.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  charge
# cost_with_battery:  0.016935564701373064
# cost_without_battery:  0.00764446955021889
# reward:  -0.009291095151154175
# #####
#
# #####
# timestamp:  16
# battery_capacity:  280.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  charge
# cost_with_battery:  0.01256093661232964
# cost_without_battery:  0.004402462860941112
# reward:  -0.008158473751388527
# #####
#
# #####
# timestamp:  17
# battery_capacity:  300.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  charge
# cost_with_battery:  0.013580901622242828
# cost_without_battery:  0.005142917588314595
# reward:  -0.008437984033928233
# #####
#
# #####
# timestamp:  18
# battery_capacity:  320.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  charge
# cost_with_battery:  0.014256653308666267
# cost_without_battery:  0.005639133158731313
# reward:  -0.008617520149934953
# #####
#
# #####
# timestamp:  19
# battery_capacity:  340.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  charge
# cost_with_battery:  0.013427927449047226
# cost_without_battery:  0.0050311910203113125
# reward:  -0.008396736428735913
# #####
#
# #####
# timestamp:  20
# battery_capacity:  360.0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  idle
# cost_with_battery:  0.132254245209227
# cost_without_battery:  0.132254245209227
# reward:  0.0
# #####
#
# #####
# timestamp:  21
# battery_capacity:  360.0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  idle
# cost_with_battery:  0.10106125774188911
# cost_without_battery:  0.10106125774188911
# reward:  0.0
# #####
#
# #####
# timestamp:  22
# battery_capacity:  360.0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  charge
# cost_with_battery:  0.21368539601167863
# cost_without_battery:  0.18343233490610006
# reward:  -0.03025306110557857
# #####
#
# #####
# timestamp:  23
# battery_capacity:  380.0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  charge
# cost_with_battery:  0.19345276725742247
# cost_without_battery:  0.16461733895050235
# reward:  -0.028835428306920124
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  idle
# cost_with_battery:  0.009063475574313713
# cost_without_battery:  0.009063475574313713
# reward:  0.0
# #####
#
# #####
# timestamp:  1
# battery_capacity:  100.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  idle
# cost_with_battery:  0.007104716473000415
# cost_without_battery:  0.007104716473000415
# reward:  0.0
# #####
#
# #####
# timestamp:  2
# battery_capacity:  100.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  idle
# cost_with_battery:  0.007727980414057924
# cost_without_battery:  0.007727980414057924
# reward:  0.0
# #####
#
# #####
# timestamp:  3
# battery_capacity:  100.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  charge
# cost_with_battery:  0.016872273728930284
# cost_without_battery:  0.007596459876763167
# reward:  -0.009275813852167117
# #####
#
# #####
# timestamp:  4
# battery_capacity:  120.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  idle
# cost_with_battery:  0.005649080236401385
# cost_without_battery:  0.005649080236401385
# reward:  0.0
# #####
#
# #####
# timestamp:  5
# battery_capacity:  120.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  charge
# cost_with_battery:  0.01613802528163363
# cost_without_battery:  0.007041600075004809
# reward:  -0.00909642520662882
# #####
#
# #####
# timestamp:  6
# battery_capacity:  140.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  charge
# cost_with_battery:  0.017273311877481375
# cost_without_battery:  0.007901140862151749
# reward:  -0.009372171015329627
# #####
#
# #####
# timestamp:  7
# battery_capacity:  160.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  idle
# cost_with_battery:  0.0069704510563527
# cost_without_battery:  0.0069704510563527
# reward:  0.0
# #####
#
# #####
# timestamp:  8
# battery_capacity:  160.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  charge
# cost_with_battery:  0.01901491471884383
# cost_without_battery:  0.00923655160973429
# reward:  -0.009778363109109539
# #####
#
# #####
# timestamp:  9
# battery_capacity:  180.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  charge
# cost_with_battery:  0.015954801764766123
# cost_without_battery:  0.00690376412610957
# reward:  -0.009051037638656553
# #####
#
# #####
# timestamp:  10
# battery_capacity:  200.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  charge
# cost_with_battery:  0.015578095721321376
# cost_without_battery:  0.006621187849208898
# reward:  -0.008956907872112478
# #####
#
# #####
# timestamp:  11
# battery_capacity:  220.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  charge
# cost_with_battery:  0.015032220278380234
# cost_without_battery:  0.006213724188113198
# reward:  -0.008818496090267035
# #####
#
# #####
# timestamp:  12
# battery_capacity:  240.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  charge
# cost_with_battery:  0.017953735578226833
# cost_without_battery:  0.00842056838703063
# reward:  -0.009533167191196203
# #####
#
# #####
# timestamp:  13
# battery_capacity:  260.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  charge
# cost_with_battery:  0.018173773485149407
# cost_without_battery:  0.008589188816069742
# reward:  -0.009584584669079665
# #####
#
# #####
# timestamp:  14
# battery_capacity:  280.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  charge
# cost_with_battery:  0.017403816315930073
# cost_without_battery:  0.008000527360781601
# reward:  -0.009403288955148472
# #####
#
# #####
# timestamp:  15
# battery_capacity:  300.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  idle
# cost_with_battery:  0.00764446955021889
# cost_without_battery:  0.00764446955021889
# reward:  0.0
# #####
#
# #####
# timestamp:  16
# battery_capacity:  300.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  idle
# cost_with_battery:  0.004402462860941112
# cost_without_battery:  0.004402462860941112
# reward:  0.0
# #####
#
# #####
# timestamp:  17
# battery_capacity:  300.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  idle
# cost_with_battery:  0.005142917588314595
# cost_without_battery:  0.005142917588314595
# reward:  0.0
# #####
#
# #####
# timestamp:  18
# battery_capacity:  300.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  idle
# cost_with_battery:  0.005639133158731313
# cost_without_battery:  0.005639133158731313
# reward:  0.0
# #####
#
# #####
# timestamp:  19
# battery_capacity:  300.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  discharge
# action is battery_discharge:  11.983682143679562
# cost_with_battery:  0.0
# cost_without_battery:  0.0050311910203113125
# reward:  0.0050311910203113125
# #####
#
# #####
# timestamp:  20
# battery_capacity:  280.0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  charge
# cost_with_battery:  0.1584494382637568
# cost_without_battery:  0.132254245209227
# reward:  -0.026195193054529803
# #####
#
# #####
# timestamp:  21
# battery_capacity:  300.0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  charge
# cost_with_battery:  0.12438968687371227
# cost_without_battery:  0.10106125774188911
# reward:  -0.02332842913182316
# #####
#
# #####
# timestamp:  22
# battery_capacity:  320.0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  charge
# cost_with_battery:  0.21368539601167863
# cost_without_battery:  0.18343233490610006
# reward:  -0.03025306110557857
# #####
#
# #####
# timestamp:  23
# battery_capacity:  340.0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  charge
# cost_with_battery:  0.19345276725742247
# cost_without_battery:  0.16461733895050235
# reward:  -0.028835428306920124
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  idle
# cost_with_battery:  0.009063475574313713
# cost_without_battery:  0.009063475574313713
# reward:  0.0
# #####
#
# #####
# timestamp:  1
# battery_capacity:  100.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  idle
# cost_with_battery:  0.007104716473000415
# cost_without_battery:  0.007104716473000415
# reward:  0.0
# #####
#
# #####
# timestamp:  2
# battery_capacity:  100.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  idle
# cost_with_battery:  0.007727980414057924
# cost_without_battery:  0.007727980414057924
# reward:  0.0
# #####
#
# #####
# timestamp:  3
# battery_capacity:  100.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  idle
# cost_with_battery:  0.007596459876763167
# cost_without_battery:  0.007596459876763167
# reward:  0.0
# #####
#
# #####
# timestamp:  4
# battery_capacity:  100.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  charge
# cost_with_battery:  0.014270140718695234
# cost_without_battery:  0.005649080236401385
# reward:  -0.008621060482293849
# #####
#
# #####
# timestamp:  5
# battery_capacity:  120.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  idle
# cost_with_battery:  0.007041600075004809
# cost_without_battery:  0.007041600075004809
# reward:  0.0
# #####
#
# #####
# timestamp:  6
# battery_capacity:  120.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  charge
# cost_with_battery:  0.017273311877481375
# cost_without_battery:  0.007901140862151749
# reward:  -0.009372171015329627
# #####
#
# #####
# timestamp:  7
# battery_capacity:  140.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  charge
# cost_with_battery:  0.016043490182310213
# cost_without_battery:  0.0069704510563527
# reward:  -0.009073039125957513
# #####
#
# #####
# timestamp:  8
# battery_capacity:  160.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  idle
# cost_with_battery:  0.00923655160973429
# cost_without_battery:  0.00923655160973429
# reward:  0.0
# #####
#
# #####
# timestamp:  9
# battery_capacity:  160.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  charge
# cost_with_battery:  0.015954801764766123
# cost_without_battery:  0.00690376412610957
# reward:  -0.009051037638656553
# #####
#
# #####
# timestamp:  10
# battery_capacity:  180.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  discharge
# action is battery_discharge:  14.784539360562382
# cost_with_battery:  0.0
# cost_without_battery:  0.006621187849208898
# reward:  0.006621187849208898
# #####
#
# #####
# timestamp:  11
# battery_capacity:  160.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  charge
# cost_with_battery:  0.015032220278380234
# cost_without_battery:  0.006213724188113198
# reward:  -0.008818496090267035
# #####
#
# #####
# timestamp:  12
# battery_capacity:  180.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  charge
# cost_with_battery:  0.017953735578226833
# cost_without_battery:  0.00842056838703063
# reward:  -0.009533167191196203
# #####
#
# #####
# timestamp:  13
# battery_capacity:  200.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  charge
# cost_with_battery:  0.018173773485149407
# cost_without_battery:  0.008589188816069742
# reward:  -0.009584584669079665
# #####
#
# #####
# timestamp:  14
# battery_capacity:  220.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  charge
# cost_with_battery:  0.017403816315930073
# cost_without_battery:  0.008000527360781601
# reward:  -0.009403288955148472
# #####
#
# #####
# timestamp:  15
# battery_capacity:  240.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  charge
# cost_with_battery:  0.016935564701373064
# cost_without_battery:  0.00764446955021889
# reward:  -0.009291095151154175
# #####
#
# #####
# timestamp:  16
# battery_capacity:  260.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  charge
# cost_with_battery:  0.01256093661232964
# cost_without_battery:  0.004402462860941112
# reward:  -0.008158473751388527
# #####
#
# #####
# timestamp:  17
# battery_capacity:  280.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  charge
# cost_with_battery:  0.013580901622242828
# cost_without_battery:  0.005142917588314595
# reward:  -0.008437984033928233
# #####
#
# #####
# timestamp:  18
# battery_capacity:  300.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  idle
# cost_with_battery:  0.005639133158731313
# cost_without_battery:  0.005639133158731313
# reward:  0.0
# #####
#
# #####
# timestamp:  19
# battery_capacity:  300.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  discharge
# action is battery_discharge:  11.983682143679562
# cost_with_battery:  0.0
# cost_without_battery:  0.0050311910203113125
# reward:  0.0050311910203113125
# #####
#
# #####
# timestamp:  20
# battery_capacity:  280.0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  idle
# cost_with_battery:  0.132254245209227
# cost_without_battery:  0.132254245209227
# reward:  0.0
# #####
#
# #####
# timestamp:  21
# battery_capacity:  280.0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  charge
# cost_with_battery:  0.12438968687371227
# cost_without_battery:  0.10106125774188911
# reward:  -0.02332842913182316
# #####
#
# #####
# timestamp:  22
# battery_capacity:  300.0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  charge
# cost_with_battery:  0.21368539601167863
# cost_without_battery:  0.18343233490610006
# reward:  -0.03025306110557857
# #####
#
# #####
# timestamp:  23
# battery_capacity:  320.0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  charge
# cost_with_battery:  0.19345276725742247
# cost_without_battery:  0.16461733895050235
# reward:  -0.028835428306920124
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  idle
# cost_with_battery:  0.009063475574313713
# cost_without_battery:  0.009063475574313713
# reward:  0.0
# #####
#
# #####
# timestamp:  1
# battery_capacity:  100.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  idle
# cost_with_battery:  0.007104716473000415
# cost_without_battery:  0.007104716473000415
# reward:  0.0
# #####
#
# #####
# timestamp:  2
# battery_capacity:  100.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  idle
# cost_with_battery:  0.007727980414057924
# cost_without_battery:  0.007727980414057924
# reward:  0.0
# #####
#
# #####
# timestamp:  3
# battery_capacity:  100.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  idle
# cost_with_battery:  0.007596459876763167
# cost_without_battery:  0.007596459876763167
# reward:  0.0
# #####
#
# #####
# timestamp:  4
# battery_capacity:  100.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  idle
# cost_with_battery:  0.005649080236401385
# cost_without_battery:  0.005649080236401385
# reward:  0.0
# #####
#
# #####
# timestamp:  5
# battery_capacity:  100.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  charge
# cost_with_battery:  0.01613802528163363
# cost_without_battery:  0.007041600075004809
# reward:  -0.00909642520662882
# #####
#
# #####
# timestamp:  6
# battery_capacity:  120.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  idle
# cost_with_battery:  0.007901140862151749
# cost_without_battery:  0.007901140862151749
# reward:  0.0
# #####
#
# #####
# timestamp:  7
# battery_capacity:  120.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  charge
# cost_with_battery:  0.016043490182310213
# cost_without_battery:  0.0069704510563527
# reward:  -0.009073039125957513
# #####
#
# #####
# timestamp:  8
# battery_capacity:  140.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  charge
# cost_with_battery:  0.01901491471884383
# cost_without_battery:  0.00923655160973429
# reward:  -0.009778363109109539
# #####
#
# #####
# timestamp:  9
# battery_capacity:  160.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  idle
# cost_with_battery:  0.00690376412610957
# cost_without_battery:  0.00690376412610957
# reward:  0.0
# #####
#
# #####
# timestamp:  10
# battery_capacity:  160.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  charge
# cost_with_battery:  0.015578095721321376
# cost_without_battery:  0.006621187849208898
# reward:  -0.008956907872112478
# #####
#
# #####
# timestamp:  11
# battery_capacity:  180.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  charge
# cost_with_battery:  0.015032220278380234
# cost_without_battery:  0.006213724188113198
# reward:  -0.008818496090267035
# #####
#
# #####
# timestamp:  12
# battery_capacity:  200.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  charge
# cost_with_battery:  0.017953735578226833
# cost_without_battery:  0.00842056838703063
# reward:  -0.009533167191196203
# #####
#
# #####
# timestamp:  13
# battery_capacity:  220.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  charge
# cost_with_battery:  0.018173773485149407
# cost_without_battery:  0.008589188816069742
# reward:  -0.009584584669079665
# #####
#
# #####
# timestamp:  14
# battery_capacity:  240.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  idle
# cost_with_battery:  0.008000527360781601
# cost_without_battery:  0.008000527360781601
# reward:  0.0
# #####
#
# #####
# timestamp:  15
# battery_capacity:  240.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  idle
# cost_with_battery:  0.00764446955021889
# cost_without_battery:  0.00764446955021889
# reward:  0.0
# #####
#
# #####
# timestamp:  16
# battery_capacity:  240.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  charge
# cost_with_battery:  0.01256093661232964
# cost_without_battery:  0.004402462860941112
# reward:  -0.008158473751388527
# #####
#
# #####
# timestamp:  17
# battery_capacity:  260.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  charge
# cost_with_battery:  0.013580901622242828
# cost_without_battery:  0.005142917588314595
# reward:  -0.008437984033928233
# #####
#
# #####
# timestamp:  18
# battery_capacity:  280.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  charge
# cost_with_battery:  0.014256653308666267
# cost_without_battery:  0.005639133158731313
# reward:  -0.008617520149934953
# #####
#
# #####
# timestamp:  19
# battery_capacity:  300.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  discharge
# action is battery_discharge:  11.983682143679562
# cost_with_battery:  0.0
# cost_without_battery:  0.0050311910203113125
# reward:  0.0050311910203113125
# #####
#
# #####
# timestamp:  20
# battery_capacity:  280.0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  idle
# cost_with_battery:  0.132254245209227
# cost_without_battery:  0.132254245209227
# reward:  0.0
# #####
#
# #####
# timestamp:  21
# battery_capacity:  280.0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  idle
# cost_with_battery:  0.10106125774188911
# cost_without_battery:  0.10106125774188911
# reward:  0.0
# #####
#
# #####
# timestamp:  22
# battery_capacity:  280.0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  charge
# cost_with_battery:  0.21368539601167863
# cost_without_battery:  0.18343233490610006
# reward:  -0.03025306110557857
# #####
#
# #####
# timestamp:  23
# battery_capacity:  300.0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  charge
# cost_with_battery:  0.19345276725742247
# cost_without_battery:  0.16461733895050235
# reward:  -0.028835428306920124
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  idle
# cost_with_battery:  0.009063475574313713
# cost_without_battery:  0.009063475574313713
# reward:  0.0
# #####
#
# #####
# timestamp:  1
# battery_capacity:  100.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  idle
# cost_with_battery:  0.007104716473000415
# cost_without_battery:  0.007104716473000415
# reward:  0.0
# #####
#
# #####
# timestamp:  2
# battery_capacity:  100.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  idle
# cost_with_battery:  0.007727980414057924
# cost_without_battery:  0.007727980414057924
# reward:  0.0
# #####
#
# #####
# timestamp:  3
# battery_capacity:  100.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  idle
# cost_with_battery:  0.007596459876763167
# cost_without_battery:  0.007596459876763167
# reward:  0.0
# #####
#
# #####
# timestamp:  4
# battery_capacity:  100.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  idle
# cost_with_battery:  0.005649080236401385
# cost_without_battery:  0.005649080236401385
# reward:  0.0
# #####
#
# #####
# timestamp:  5
# battery_capacity:  100.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  idle
# cost_with_battery:  0.007041600075004809
# cost_without_battery:  0.007041600075004809
# reward:  0.0
# #####
#
# #####
# timestamp:  6
# battery_capacity:  100.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  charge
# cost_with_battery:  0.017273311877481375
# cost_without_battery:  0.007901140862151749
# reward:  -0.009372171015329627
# #####
#
# #####
# timestamp:  7
# battery_capacity:  120.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  idle
# cost_with_battery:  0.0069704510563527
# cost_without_battery:  0.0069704510563527
# reward:  0.0
# #####
#
# #####
# timestamp:  8
# battery_capacity:  120.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  idle
# cost_with_battery:  0.00923655160973429
# cost_without_battery:  0.00923655160973429
# reward:  0.0
# #####
#
# #####
# timestamp:  9
# battery_capacity:  120.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  charge
# cost_with_battery:  0.015954801764766123
# cost_without_battery:  0.00690376412610957
# reward:  -0.009051037638656553
# #####
#
# #####
# timestamp:  10
# battery_capacity:  140.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  charge
# cost_with_battery:  0.015578095721321376
# cost_without_battery:  0.006621187849208898
# reward:  -0.008956907872112478
# #####
#
# #####
# timestamp:  11
# battery_capacity:  160.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  idle
# cost_with_battery:  0.006213724188113198
# cost_without_battery:  0.006213724188113198
# reward:  0.0
# #####
#
# #####
# timestamp:  12
# battery_capacity:  160.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  charge
# cost_with_battery:  0.017953735578226833
# cost_without_battery:  0.00842056838703063
# reward:  -0.009533167191196203
# #####
#
# #####
# timestamp:  13
# battery_capacity:  180.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  idle
# cost_with_battery:  0.008589188816069742
# cost_without_battery:  0.008589188816069742
# reward:  0.0
# #####
#
# #####
# timestamp:  14
# battery_capacity:  180.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  discharge
# action is battery_discharge:  17.016444775742357
# cost_with_battery:  0.0
# cost_without_battery:  0.008000527360781601
# reward:  0.008000527360781601
# #####
#
# #####
# timestamp:  15
# battery_capacity:  160.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  charge
# cost_with_battery:  0.016935564701373064
# cost_without_battery:  0.00764446955021889
# reward:  -0.009291095151154175
# #####
#
# #####
# timestamp:  16
# battery_capacity:  180.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  charge
# cost_with_battery:  0.01256093661232964
# cost_without_battery:  0.004402462860941112
# reward:  -0.008158473751388527
# #####
#
# #####
# timestamp:  17
# battery_capacity:  200.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  charge
# cost_with_battery:  0.013580901622242828
# cost_without_battery:  0.005142917588314595
# reward:  -0.008437984033928233
# #####
#
# #####
# timestamp:  18
# battery_capacity:  220.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  charge
# cost_with_battery:  0.014256653308666267
# cost_without_battery:  0.005639133158731313
# reward:  -0.008617520149934953
# #####
#
# #####
# timestamp:  19
# battery_capacity:  240.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  charge
# cost_with_battery:  0.013427927449047226
# cost_without_battery:  0.0050311910203113125
# reward:  -0.008396736428735913
# #####
#
# #####
# timestamp:  20
# battery_capacity:  260.0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  charge
# cost_with_battery:  0.1584494382637568
# cost_without_battery:  0.132254245209227
# reward:  -0.026195193054529803
# #####
#
# #####
# timestamp:  21
# battery_capacity:  280.0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  idle
# cost_with_battery:  0.10106125774188911
# cost_without_battery:  0.10106125774188911
# reward:  0.0
# #####
#
# #####
# timestamp:  22
# battery_capacity:  280.0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  idle
# cost_with_battery:  0.18343233490610006
# cost_without_battery:  0.18343233490610006
# reward:  0.0
# #####
#
# #####
# timestamp:  23
# battery_capacity:  280.0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  charge
# cost_with_battery:  0.19345276725742247
# cost_without_battery:  0.16461733895050235
# reward:  -0.028835428306920124
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  idle
# cost_with_battery:  0.009063475574313713
# cost_without_battery:  0.009063475574313713
# reward:  0.0
# #####
#
# #####
# timestamp:  1
# battery_capacity:  100.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  idle
# cost_with_battery:  0.007104716473000415
# cost_without_battery:  0.007104716473000415
# reward:  0.0
# #####
#
# #####
# timestamp:  2
# battery_capacity:  100.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  idle
# cost_with_battery:  0.007727980414057924
# cost_without_battery:  0.007727980414057924
# reward:  0.0
# #####
#
# #####
# timestamp:  3
# battery_capacity:  100.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  idle
# cost_with_battery:  0.007596459876763167
# cost_without_battery:  0.007596459876763167
# reward:  0.0
# #####
#
# #####
# timestamp:  4
# battery_capacity:  100.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  discharge
# action is battery_discharge:  13.105302411469237
# cost_with_battery:  0.0
# cost_without_battery:  0.005649080236401385
# reward:  0.005649080236401385
# #####
#
# #####
# timestamp:  5
# battery_capacity:  80.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  charge
# cost_with_battery:  0.01613802528163363
# cost_without_battery:  0.007041600075004809
# reward:  -0.00909642520662882
# #####
#
# #####
# timestamp:  6
# battery_capacity:  100.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  idle
# cost_with_battery:  0.007901140862151749
# cost_without_battery:  0.007901140862151749
# reward:  0.0
# #####
#
# #####
# timestamp:  7
# battery_capacity:  100.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  charge
# cost_with_battery:  0.016043490182310213
# cost_without_battery:  0.0069704510563527
# reward:  -0.009073039125957513
# #####
#
# #####
# timestamp:  8
# battery_capacity:  120.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  charge
# cost_with_battery:  0.01901491471884383
# cost_without_battery:  0.00923655160973429
# reward:  -0.009778363109109539
# #####
#
# #####
# timestamp:  9
# battery_capacity:  140.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  charge
# cost_with_battery:  0.015954801764766123
# cost_without_battery:  0.00690376412610957
# reward:  -0.009051037638656553
# #####
#
# #####
# timestamp:  10
# battery_capacity:  160.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  idle
# cost_with_battery:  0.006621187849208898
# cost_without_battery:  0.006621187849208898
# reward:  0.0
# #####
#
# #####
# timestamp:  11
# battery_capacity:  160.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  idle
# cost_with_battery:  0.006213724188113198
# cost_without_battery:  0.006213724188113198
# reward:  0.0
# #####
#
# #####
# timestamp:  12
# battery_capacity:  160.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  idle
# cost_with_battery:  0.00842056838703063
# cost_without_battery:  0.00842056838703063
# reward:  0.0
# #####
#
# #####
# timestamp:  13
# battery_capacity:  160.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  idle
# cost_with_battery:  0.008589188816069742
# cost_without_battery:  0.008589188816069742
# reward:  0.0
# #####
#
# #####
# timestamp:  14
# battery_capacity:  160.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  charge
# cost_with_battery:  0.017403816315930073
# cost_without_battery:  0.008000527360781601
# reward:  -0.009403288955148472
# #####
#
# #####
# timestamp:  15
# battery_capacity:  180.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  charge
# cost_with_battery:  0.016935564701373064
# cost_without_battery:  0.00764446955021889
# reward:  -0.009291095151154175
# #####
#
# #####
# timestamp:  16
# battery_capacity:  200.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  charge
# cost_with_battery:  0.01256093661232964
# cost_without_battery:  0.004402462860941112
# reward:  -0.008158473751388527
# #####
#
# #####
# timestamp:  17
# battery_capacity:  220.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  charge
# cost_with_battery:  0.013580901622242828
# cost_without_battery:  0.005142917588314595
# reward:  -0.008437984033928233
# #####
#
# #####
# timestamp:  18
# battery_capacity:  240.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  charge
# cost_with_battery:  0.014256653308666267
# cost_without_battery:  0.005639133158731313
# reward:  -0.008617520149934953
# #####
#
# #####
# timestamp:  19
# battery_capacity:  260.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  charge
# cost_with_battery:  0.013427927449047226
# cost_without_battery:  0.0050311910203113125
# reward:  -0.008396736428735913
# #####
#
# #####
# timestamp:  20
# battery_capacity:  280.0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  idle
# cost_with_battery:  0.132254245209227
# cost_without_battery:  0.132254245209227
# reward:  0.0
# #####
#
# #####
# timestamp:  21
# battery_capacity:  280.0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  idle
# cost_with_battery:  0.10106125774188911
# cost_without_battery:  0.10106125774188911
# reward:  0.0
# #####
#
# #####
# timestamp:  22
# battery_capacity:  280.0
# ...
# cost_without_battery:  0.00923655160973429
# reward:  0.0
# #####
#
# #####
# timestamp:  9
# battery_capacity:  60.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  discharge
# action is battery_discharge:  15.255188193282766
# cost_with_battery:  0.0
# cost_without_battery:  0.00690376412610957
# reward:  0.00690376412610957
# #####
#
# #####
# timestamp:  10
# battery_capacity:  40.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  discharge
# action is battery_discharge:  14.784539360562382
# cost_with_battery:  0.0
# cost_without_battery:  0.006621187849208898
# reward:  0.006621187849208898
# #####
#
# #####
# timestamp:  11
# battery_capacity:  20.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  discharge
# action is battery_discharge:  14.092480451335184
# cost_with_battery:  0.0
# cost_without_battery:  0.006213724188113198
# reward:  0.006213724188113198
# #####
#
# #####
# timestamp:  12
# battery_capacity:  0.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  idle
# cost_with_battery:  0.00842056838703063
# cost_without_battery:  0.00842056838703063
# reward:  0.0
# #####
#
# #####
# timestamp:  13
# battery_capacity:  0.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  charge
# cost_with_battery:  0.018173773485149407
# cost_without_battery:  0.008589188816069742
# reward:  -0.009584584669079665
# #####
#
# #####
# timestamp:  14
# battery_capacity:  20.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  idle
# cost_with_battery:  0.008000527360781601
# cost_without_battery:  0.008000527360781601
# reward:  0.0
# #####
#
# #####
# timestamp:  15
# battery_capacity:  20.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  discharge
# action is battery_discharge:  16.45547575577087
# cost_with_battery:  0.0
# cost_without_battery:  0.00764446955021889
# reward:  0.00764446955021889
# #####
#
# #####
# timestamp:  16
# battery_capacity:  0.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  idle
# cost_with_battery:  0.004402462860941112
# cost_without_battery:  0.004402462860941112
# reward:  0.0
# #####
#
# #####
# timestamp:  17
# battery_capacity:  0.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  discharge
# action is battery_discharge:  0.0
# cost_with_battery:  0.005142917588314595
# cost_without_battery:  0.005142917588314595
# reward:  0.0
# #####
#
# #####
# timestamp:  18
# battery_capacity:  0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  idle
# cost_with_battery:  0.005639133158731313
# cost_without_battery:  0.005639133158731313
# reward:  0.0
# #####
#
# #####
# timestamp:  19
# battery_capacity:  0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  idle
# cost_with_battery:  0.0050311910203113125
# cost_without_battery:  0.0050311910203113125
# reward:  0.0
# #####
#
# #####
# timestamp:  20
# battery_capacity:  0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  idle
# cost_with_battery:  0.132254245209227
# cost_without_battery:  0.132254245209227
# reward:  0.0
# #####
#
# #####
# timestamp:  21
# battery_capacity:  0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  idle
# cost_with_battery:  0.10106125774188911
# cost_without_battery:  0.10106125774188911
# reward:  0.0
# #####
#
# #####
# timestamp:  22
# battery_capacity:  0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  idle
# cost_with_battery:  0.18343233490610006
# cost_without_battery:  0.18343233490610006
# reward:  0.0
# #####
#
# #####
# timestamp:  23
# battery_capacity:  0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  idle
# cost_with_battery:  0.16461733895050235
# cost_without_battery:  0.16461733895050235
# reward:  0.0
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  charge
# cost_with_battery:  0.01879057764706799
# cost_without_battery:  0.009063475574313713
# reward:  -0.009727102072754276
# #####
#
# #####
# timestamp:  1
# battery_capacity:  120.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  idle
# cost_with_battery:  0.007104716473000415
# cost_without_battery:  0.007104716473000415
# reward:  0.0
# #####
#
# #####
# timestamp:  2
# battery_capacity:  120.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  idle
# cost_with_battery:  0.007727980414057924
# cost_without_battery:  0.007727980414057924
# reward:  0.0
# #####
#
# #####
# timestamp:  3
# battery_capacity:  120.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  discharge
# action is battery_discharge:  16.379069260835585
# cost_with_battery:  0.0
# cost_without_battery:  0.007596459876763167
# reward:  0.007596459876763167
# #####
#
# #####
# timestamp:  4
# battery_capacity:  100.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  discharge
# action is battery_discharge:  13.105302411469237
# cost_with_battery:  0.0
# cost_without_battery:  0.005649080236401385
# reward:  0.005649080236401385
# #####
#
# #####
# timestamp:  5
# battery_capacity:  80.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  discharge
# action is battery_discharge:  15.482126033144095
# cost_with_battery:  0.0
# cost_without_battery:  0.007041600075004809
# reward:  0.007041600075004809
# #####
#
# #####
# timestamp:  6
# battery_capacity:  60.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  idle
# cost_with_battery:  0.007901140862151749
# cost_without_battery:  0.007901140862151749
# reward:  0.0
# #####
#
# #####
# timestamp:  7
# battery_capacity:  60.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  idle
# cost_with_battery:  0.0069704510563527
# cost_without_battery:  0.0069704510563527
# reward:  0.0
# #####
#
# #####
# timestamp:  8
# battery_capacity:  60.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  idle
# cost_with_battery:  0.00923655160973429
# cost_without_battery:  0.00923655160973429
# reward:  0.0
# #####
#
# #####
# timestamp:  9
# battery_capacity:  60.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  charge
# cost_with_battery:  0.015954801764766123
# cost_without_battery:  0.00690376412610957
# reward:  -0.009051037638656553
# #####
#
# #####
# timestamp:  10
# battery_capacity:  80.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  idle
# cost_with_battery:  0.006621187849208898
# cost_without_battery:  0.006621187849208898
# reward:  0.0
# #####
#
# #####
# timestamp:  11
# battery_capacity:  80.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  idle
# cost_with_battery:  0.006213724188113198
# cost_without_battery:  0.006213724188113198
# reward:  0.0
# #####
#
# #####
# timestamp:  12
# battery_capacity:  80.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  discharge
# action is battery_discharge:  17.665835955981027
# cost_with_battery:  0.0
# cost_without_battery:  0.00842056838703063
# reward:  0.00842056838703063
# #####
#
# #####
# timestamp:  13
# battery_capacity:  60.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  discharge
# action is battery_discharge:  17.922923345398328
# cost_with_battery:  0.0
# cost_without_battery:  0.008589188816069742
# reward:  0.008589188816069742
# #####
#
# #####
# timestamp:  14
# battery_capacity:  40.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  discharge
# action is battery_discharge:  17.016444775742357
# cost_with_battery:  0.0
# cost_without_battery:  0.008000527360781601
# reward:  0.008000527360781601
# #####
#
# #####
# timestamp:  15
# battery_capacity:  20.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  discharge
# action is battery_discharge:  16.45547575577087
# cost_with_battery:  0.0
# cost_without_battery:  0.00764446955021889
# reward:  0.00764446955021889
# #####
#
# #####
# timestamp:  16
# battery_capacity:  0.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  idle
# cost_with_battery:  0.004402462860941112
# cost_without_battery:  0.004402462860941112
# reward:  0.0
# #####
#
# #####
# timestamp:  17
# battery_capacity:  0.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  idle
# cost_with_battery:  0.005142917588314595
# cost_without_battery:  0.005142917588314595
# reward:  0.0
# #####
#
# #####
# timestamp:  18
# battery_capacity:  0.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  idle
# cost_with_battery:  0.005639133158731313
# cost_without_battery:  0.005639133158731313
# reward:  0.0
# #####
#
# #####
# timestamp:  19
# battery_capacity:  0.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  idle
# cost_with_battery:  0.0050311910203113125
# cost_without_battery:  0.0050311910203113125
# reward:  0.0
# #####
#
# #####
# timestamp:  20
# battery_capacity:  0.0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  idle
# cost_with_battery:  0.132254245209227
# cost_without_battery:  0.132254245209227
# reward:  0.0
# #####
#
# #####
# timestamp:  21
# battery_capacity:  0.0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  idle
# cost_with_battery:  0.10106125774188911
# cost_without_battery:  0.10106125774188911
# reward:  0.0
# #####
#
# #####
# timestamp:  22
# battery_capacity:  0.0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  idle
# cost_with_battery:  0.18343233490610006
# cost_without_battery:  0.18343233490610006
# reward:  0.0
# #####
#
# #####
# timestamp:  23
# battery_capacity:  0.0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  idle
# cost_with_battery:  0.16461733895050235
# cost_without_battery:  0.16461733895050235
# reward:  0.0
# #####
#
# #####
# timestamp:  0
# battery_capacity:  100.0
# current_demand:  18.63551036377137
# current_price:  0.0004863551036377137
# action:  discharge
# action is battery_discharge:  18.63551036377137
# cost_with_battery:  0.0
# cost_without_battery:  0.009063475574313713
# reward:  0.009063475574313713
# #####
#
# #####
# timestamp:  1
# battery_capacity:  80.0
# current_demand:  15.585480988535092
# current_price:  0.0004558548098853509
# action:  discharge
# action is battery_discharge:  15.585480988535092
# cost_with_battery:  0.0
# cost_without_battery:  0.007104716473000415
# reward:  0.007104716473000415
# #####
#
# #####
# timestamp:  2
# battery_capacity:  60.0
# current_demand:  16.58794139233819
# current_price:  0.0004658794139233819
# action:  discharge
# action is battery_discharge:  16.58794139233819
# cost_with_battery:  0.0
# cost_without_battery:  0.007727980414057924
# reward:  0.007727980414057924
# #####
#
# #####
# timestamp:  3
# battery_capacity:  40.0
# current_demand:  16.379069260835585
# current_price:  0.0004637906926083558
# action:  discharge
# action is battery_discharge:  16.379069260835585
# cost_with_battery:  0.0
# cost_without_battery:  0.007596459876763167
# reward:  0.007596459876763167
# #####
#
# #####
# timestamp:  4
# battery_capacity:  20.0
# current_demand:  13.105302411469237
# current_price:  0.0004310530241146924
# action:  discharge
# action is battery_discharge:  13.105302411469237
# cost_with_battery:  0.0
# cost_without_battery:  0.005649080236401385
# reward:  0.005649080236401385
# #####
#
# #####
# timestamp:  5
# battery_capacity:  0.0
# current_demand:  15.482126033144095
# current_price:  0.0004548212603314409
# action:  idle
# cost_with_battery:  0.007041600075004809
# cost_without_battery:  0.007041600075004809
# reward:  0.0
# #####
#
# #####
# timestamp:  6
# battery_capacity:  0.0
# current_demand:  16.86085507664813
# current_price:  0.0004686085507664813
# action:  idle
# cost_with_battery:  0.007901140862151749
# cost_without_battery:  0.007901140862151749
# reward:  0.0
# #####
#
# #####
# timestamp:  7
# battery_capacity:  0.0
# current_demand:  15.365195629787568
# current_price:  0.0004536519562978757
# action:  idle
# cost_with_battery:  0.0069704510563527
# cost_without_battery:  0.0069704510563527
# reward:  0.0
# #####
#
# #####
# timestamp:  8
# battery_capacity:  0.0
# current_demand:  18.891815545547704
# current_price:  0.000488918155455477
# action:  idle
# cost_with_battery:  0.00923655160973429
# cost_without_battery:  0.00923655160973429
# reward:  0.0
# #####
#
# #####
# timestamp:  9
# battery_capacity:  0.0
# current_demand:  15.255188193282766
# current_price:  0.0004525518819328277
# action:  idle
# cost_with_battery:  0.00690376412610957
# cost_without_battery:  0.00690376412610957
# reward:  0.0
# #####
#
# #####
# timestamp:  10
# battery_capacity:  0.0
# current_demand:  14.784539360562382
# current_price:  0.00044784539360562383
# action:  idle
# cost_with_battery:  0.006621187849208898
# cost_without_battery:  0.006621187849208898
# reward:  0.0
# #####
#
# #####
# timestamp:  11
# battery_capacity:  0.0
# current_demand:  14.092480451335184
# current_price:  0.0004409248045133518
# action:  idle
# cost_with_battery:  0.006213724188113198
# cost_without_battery:  0.006213724188113198
# reward:  0.0
# #####
#
# #####
# timestamp:  12
# battery_capacity:  0.0
# current_demand:  17.665835955981027
# current_price:  0.0004766583595598103
# action:  idle
# cost_with_battery:  0.00842056838703063
# cost_without_battery:  0.00842056838703063
# reward:  0.0
# #####
#
# #####
# timestamp:  13
# battery_capacity:  0.0
# current_demand:  17.922923345398328
# current_price:  0.00047922923345398327
# action:  idle
# cost_with_battery:  0.008589188816069742
# cost_without_battery:  0.008589188816069742
# reward:  0.0
# #####
#
# #####
# timestamp:  14
# battery_capacity:  0.0
# current_demand:  17.016444775742357
# current_price:  0.00047016444775742355
# action:  idle
# cost_with_battery:  0.008000527360781601
# cost_without_battery:  0.008000527360781601
# reward:  0.0
# #####
#
# #####
# timestamp:  15
# battery_capacity:  0.0
# current_demand:  16.45547575577087
# current_price:  0.0004645547575577087
# action:  charge
# cost_with_battery:  0.016935564701373064
# cost_without_battery:  0.00764446955021889
# reward:  -0.009291095151154175
# #####
#
# #####
# timestamp:  16
# battery_capacity:  20.0
# current_demand:  10.792368756942647
# current_price:  0.00040792368756942645
# action:  discharge
# action is battery_discharge:  10.792368756942647
# cost_with_battery:  0.0
# cost_without_battery:  0.004402462860941112
# reward:  0.004402462860941112
# #####
#
# #####
# timestamp:  17
# battery_capacity:  0.0
# current_demand:  12.189920169641168
# current_price:  0.00042189920169641163
# action:  idle
# cost_with_battery:  0.005142917588314595
# cost_without_battery:  0.005142917588314595
# reward:  0.0
# #####
#
# #####
# timestamp:  18
# battery_capacity:  0.0
# current_demand:  13.087600749674781
# current_price:  0.0004308760074967478
# action:  idle
# cost_with_battery:  0.005639133158731313
# cost_without_battery:  0.005639133158731313
# reward:  0.0
# #####
#
# #####
# timestamp:  19
# battery_capacity:  0.0
# current_demand:  11.983682143679562
# current_price:  0.00041983682143679563
# action:  discharge
# action is battery_discharge:  0.0
# cost_with_battery:  0.0050311910203113125
# cost_without_battery:  0.0050311910203113125
# reward:  0.0
# #####
#
# #####
# timestamp:  20
# battery_capacity:  0
# current_demand:  100.97596527264905
# current_price:  0.0013097596527264904
# action:  idle
# cost_with_battery:  0.132254245209227
# cost_without_battery:  0.132254245209227
# reward:  0.0
# #####
#
# #####
# timestamp:  21
# battery_capacity:  0
# current_demand:  86.6421456591158
# current_price:  0.0011664214565911578
# action:  idle
# cost_with_battery:  0.10106125774188911
# cost_without_battery:  0.10106125774188911
# reward:  0.0
# #####
#
# #####
# timestamp:  22
# battery_capacity:  0
# current_demand:  121.26530552789292
# current_price:  0.0015126530552789293
# action:  idle
# cost_with_battery:  0.18343233490610006
# cost_without_battery:  0.18343233490610006
# reward:  0.0
# #####
#
# #####
# timestamp:  23
# battery_capacity:  0
# current_demand:  114.1771415346006
# current_price:  0.001441771415346006
# action:  idle
# cost_with_battery:  0.16461733895050235
# cost_without_battery:  0.16461733895050235
# reward:  0.0
# #####

# %%
# Calculate the cumulative reward for each episode
cumulative_rewards = np.cumsum(total_rewards)
# Plot the cumulative reward of each episode
plt.plot(cumulative_rewards)
plt.xlabel('Episode')
plt.ylabel('Cumulative Reward')
plt.title('Cumulative Reward over Episodes')
plt.show()

# %%
# Print the final Q-table
#for state, actions in Q_table.items():
#    print(f'State: {state}')
#    for action, Q_value in actions.items():
#        print(f'    Action: {action}, Q-value: {Q_value}')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
